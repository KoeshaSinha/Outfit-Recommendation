# %% [markdown]
# # Upload Dataset & Unzip

# %%
# !unzip /content/polyvore-outfits.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: polyvore_outfits/images/90489434.jpg
#   inflating: polyvore_outfits/images/90492213.jpg
#   inflating: polyvore_outfits/images/90492494.jpg
#   inflating: polyvore_outfits/images/90496029.jpg
#   inflating: polyvore_outfits/images/90497446.jpg
#   inflating: polyvore_outfits/images/90518135.jpg
#   inflating: polyvore_outfits/images/90518552.jpg
#   inflating: polyvore_outfits/images/90521419.jpg
#   inflating: polyvore_outfits/images/90524054.jpg
#   inflating: polyvore_outfits/images/90531717.jpg
#   inflating: polyvore_outfits/images/90537718.jpg
#   inflating: polyvore_outfits/images/90539482.jpg
#   inflating: polyvore_outfits/images/90540596.jpg
#   inflating: polyvore_outfits/images/90541187.jpg
#   inflating: polyvore_outfits/images/90543355.jpg
#   inflating: polyvore_outfits/images/90543409.jpg
#   inflating: polyvore_outfits/images/90543514.jpg
#   inflating: polyvore_outfits/images/90543898.jpg
#   inflating: polyvore_outfits/images/90544199.jpg
#   inflating: polyvore_outfits/images/90544387.jpg
#   inflating: polyvore_outfits/images/90545434.jpg
#   inflating: polyvore_outfits/images/90547527.jpg
#   inflating: polyvore_outfits/images/90548294.jpg
#   inflating: polyvore_outfits/images/90549513.jpg
#   inflating: polyvore_outfits/images/90562284.jpg
#   inflating: polyvore_outfits/images/90564898.jpg
#   inflating: polyvore_outfits/images/90565082.jpg
#   inflating: polyvore_outfits/images/90571568.jpg
#   inflating: polyvore_outfits/images/90580258.jpg
#   inflating: polyvore_outfits/images/90581655.jpg
#   inflating: polyvore_outfits/images/90582123.jpg
#   inflating: polyvore_outfits/images/90582372.jpg
#   inflating: polyvore_outfits/images/90582529.jpg
#   inflating: polyvore_outfits/images/90586315.jpg
#   inflating: polyvore_outfits/images/90586498.jpg
#   inflating: polyvore_outfits/images/90587419.jpg
#   inflating: polyvore_outfits/images/90588168.jpg
#   inflating: polyvore_outfits/images/90590756.jpg
#   inflating: polyvore_outfits/images/90591554.jpg
#   inflating: polyvore_outfits/images/90594496.jpg
#   inflating: polyvore_outfits/images/90597702.jpg
#   inflating: polyvore_outfits/images/90598644.jpg
#   inflating: polyvore_outfits/images/90611157.jpg
#   inflating: polyvore_outfits/images/90613131.jpg
#   inflating: polyvore_outfits/images/90613138.jpg
#   inflating: polyvore_outfits/images/90613837.jpg
#   inflating: polyvore_outfits/images/90616903.jpg
#   inflating: polyvore_outfits/images/90616910.jpg
#   inflating: polyvore_outfits/images/90618766.jpg
#   inflating: polyvore_outfits/images/90618791.jpg
#   inflating: polyvore_outfits/images/90620532.jpg
#   inflating: polyvore_outfits/images/90623275.jpg
#   inflating: polyvore_outfits/images/90624139.jpg
#   inflating: polyvore_outfits/images/90625639.jpg
#   inflating: polyvore_outfits/images/90625852.jpg
#   inflating: polyvore_outfits/images/90628921.jpg
#   inflating: polyvore_outfits/images/90631231.jpg
#   inflating: polyvore_outfits/images/90631607.jpg
#   inflating: polyvore_outfits/images/90636020.jpg
#   inflating: polyvore_outfits/images/90637604.jpg
#   inflating: polyvore_outfits/images/90638603.jpg
#   inflating: polyvore_outfits/images/90640091.jpg
#   inflating: polyvore_outfits/images/90641706.jpg
#   inflating: polyvore_outfits/images/90651210.jpg
#   inflating: polyvore_outfits/images/9065274.jpg
#   inflating: polyvore_outfits/images/9065826.jpg
#   inflating: polyvore_outfits/images/90665252.jpg
#   inflating: polyvore_outfits/images/90669064.jpg
#   inflating: polyvore_outfits/images/90669977.jpg
#   inflating: polyvore_outfits/images/90671339.jpg
#   inflating: polyvore_outfits/images/90671354.jpg
#   inflating: polyvore_outfits/images/90674028.jpg
#   inflating: polyvore_outfits/images/90678596.jpg
#   inflating: polyvore_outfits/images/90682653.jpg
#   inflating: polyvore_outfits/images/90685559.jpg
#   inflating: polyvore_outfits/images/90686581.jpg
#   inflating: polyvore_outfits/images/90687768.jpg
#   inflating: polyvore_outfits/images/90691361.jpg
#   inflating: polyvore_outfits/images/90691927.jpg
#   inflating: polyvore_outfits/images/90693573.jpg
#   inflating: polyvore_outfits/images/90694324.jpg
#   inflating: polyvore_outfits/images/90695777.jpg
#   inflating: polyvore_outfits/images/90697118.jpg
#   inflating: polyvore_outfits/images/90698737.jpg
#   inflating: polyvore_outfits/images/90700227.jpg
#   inflating: polyvore_outfits/images/9070114.jpg
#   inflating: polyvore_outfits/images/90706248.jpg
#   inflating: polyvore_outfits/images/90706883.jpg
#   inflating: polyvore_outfits/images/90707300.jpg
#   inflating: polyvore_outfits/images/90708520.jpg
#   inflating: polyvore_outfits/images/90708892.jpg
#   inflating: polyvore_outfits/images/90709123.jpg
#   inflating: polyvore_outfits/images/90713978.jpg
#   inflating: polyvore_outfits/images/90717924.jpg
#   inflating: polyvore_outfits/images/90719247.jpg
#   inflating: polyvore_outfits/images/90720310.jpg
#   inflating: polyvore_outfits/images/90720327.jpg
#   inflating: polyvore_outfits/images/90722101.jpg
#   inflating: polyvore_outfits/images/90722436.jpg
#   inflating: polyvore_outfits/images/90722931.jpg
#   inflating: polyvore_outfits/images/90723833.jpg
#   inflating: polyvore_outfits/images/90724453.jpg
#   inflating: polyvore_outfits/images/90725135.jpg
#   inflating: polyvore_outfits/images/90727104.jpg
#   inflating: polyvore_outfits/images/90727989.jpg
#   inflating: polyvore_outfits/images/90728022.jpg
#   inflating: polyvore_outfits/images/90729788.jpg
#   inflating: polyvore_outfits/images/90729871.jpg
#   inflating: polyvore_outfits/images/90740456.jpg
#   inflating: polyvore_outfits/images/90748688.jpg
#   inflating: polyvore_outfits/images/90748716.jpg
#   inflating: polyvore_outfits/images/90754772.jpg
#   inflating: polyvore_outfits/images/90755055.jpg
#   inflating: polyvore_outfits/images/90755547.jpg
#   inflating: polyvore_outfits/images/90756337.jpg
#   inflating: polyvore_outfits/images/90761207.jpg
#   inflating: polyvore_outfits/images/90768659.jpg
#   inflating: polyvore_outfits/images/90769274.jpg
#   inflating: polyvore_outfits/images/90770399.jpg
#   inflating: polyvore_outfits/images/90770445.jpg
#   inflating: polyvore_outfits/images/90770777.jpg
#   inflating: polyvore_outfits/images/90771301.jpg
#   inflating: polyvore_outfits/images/90771402.jpg
#   inflating: polyvore_outfits/images/90771943.jpg
#   inflating: polyvore_outfits/images/90772340.jpg
#   inflating: polyvore_outfits/images/90772968.jpg
#   inflating: polyvore_outfits/images/90775098.jpg
#   inflating: polyvore_outfits/images/90776428.jpg
#   inflating: polyvore_outfits/images/90777121.jpg
#   inflating: polyvore_outfits/images/90778803.jpg
#   inflating: polyvore_outfits/images/90781263.jpg
#   inflating: polyvore_outfits/images/90781357.jpg
#   inflating: polyvore_outfits/images/90781547.jpg
#   inflating: polyvore_outfits/images/90783971.jpg
#   inflating: polyvore_outfits/images/90784164.jpg
#   inflating: polyvore_outfits/images/90786866.jpg
#   inflating: polyvore_outfits/images/90788168.jpg
#   inflating: polyvore_outfits/images/90790862.jpg
#   inflating: polyvore_outfits/images/90794918.jpg
#   inflating: polyvore_outfits/images/90795346.jpg
#   inflating: polyvore_outfits/images/90795630.jpg
#   inflating: polyvore_outfits/images/90796965.jpg
#   inflating: polyvore_outfits/images/90798669.jpg
#   inflating: polyvore_outfits/images/90800683.jpg
#   inflating: polyvore_outfits/images/90802350.jpg
#   inflating: polyvore_outfits/images/90809143.jpg
#   inflating: polyvore_outfits/images/90814802.jpg
#   inflating: polyvore_outfits/images/90816864.jpg
#   inflating: polyvore_outfits/images/90816984.jpg
#   inflating: polyvore_outfits/images/90819944.jpg
#   inflating: polyvore_outfits/images/90824042.jpg
#   inflating: polyvore_outfits/images/90824903.jpg
#   inflating: polyvore_outfits/images/90825720.jpg
#   inflating: polyvore_outfits/images/90825979.jpg
#   inflating: polyvore_outfits/images/90826774.jpg
#   inflating: polyvore_outfits/images/90835181.jpg
#   inflating: polyvore_outfits/images/90835377.jpg
#   inflating: polyvore_outfits/images/90845056.jpg
#   inflating: polyvore_outfits/images/90845446.jpg
#   inflating: polyvore_outfits/images/90847274.jpg
#   inflating: polyvore_outfits/images/90849785.jpg
#   inflating: polyvore_outfits/images/90849875.jpg
#   inflating: polyvore_outfits/images/90852143.jpg
#   inflating: polyvore_outfits/images/90852401.jpg
#   inflating: polyvore_outfits/images/90852458.jpg
#   inflating: polyvore_outfits/images/90854418.jpg
#   inflating: polyvore_outfits/images/90854788.jpg
#   inflating: polyvore_outfits/images/90858237.jpg
#   inflating: polyvore_outfits/images/90858594.jpg
#   inflating: polyvore_outfits/images/90859681.jpg
#   inflating: polyvore_outfits/images/90860506.jpg
#   inflating: polyvore_outfits/images/90860853.jpg
#   inflating: polyvore_outfits/images/90864382.jpg
#   inflating: polyvore_outfits/images/90864491.jpg
#   inflating: polyvore_outfits/images/90865433.jpg
#   inflating: polyvore_outfits/images/90867095.jpg
#   inflating: polyvore_outfits/images/90869005.jpg
#   inflating: polyvore_outfits/images/90869895.jpg
#   inflating: polyvore_outfits/images/90874140.jpg
#   inflating: polyvore_outfits/images/90874342.jpg
#   inflating: polyvore_outfits/images/90876536.jpg
#   inflating: polyvore_outfits/images/90876645.jpg
#   inflating: polyvore_outfits/images/90882356.jpg
#   inflating: polyvore_outfits/images/90886086.jpg
#   inflating: polyvore_outfits/images/90897593.jpg
#   inflating: polyvore_outfits/images/90898889.jpg
#   inflating: polyvore_outfits/images/90900037.jpg
#   inflating: polyvore_outfits/images/90913971.jpg
#   inflating: polyvore_outfits/images/90923236.jpg
#   inflating: polyvore_outfits/images/90931027.jpg
#   inflating: polyvore_outfits/images/90932662.jpg
#   inflating: polyvore_outfits/images/90933702.jpg
#   inflating: polyvore_outfits/images/90938976.jpg
#   inflating: polyvore_outfits/images/90939528.jpg
#   inflating: polyvore_outfits/images/90939645.jpg
#   inflating: polyvore_outfits/images/90939791.jpg
#   inflating: polyvore_outfits/images/90943637.jpg
#   inflating: polyvore_outfits/images/90948481.jpg
#   inflating: polyvore_outfits/images/90950877.jpg
#   inflating: polyvore_outfits/images/90951087.jpg
#   inflating: polyvore_outfits/images/90952487.jpg
#   inflating: polyvore_outfits/images/90953879.jpg
#   inflating: polyvore_outfits/images/90955942.jpg
#   inflating: polyvore_outfits/images/90955965.jpg
#   inflating: polyvore_outfits/images/90959447.jpg
#   inflating: polyvore_outfits/images/90965264.jpg
#   inflating: polyvore_outfits/images/90967247.jpg
#   inflating: polyvore_outfits/images/90967487.jpg
#   inflating: polyvore_outfits/images/90971857.jpg
#   inflating: polyvore_outfits/images/90977502.jpg
#   inflating: polyvore_outfits/images/90977561.jpg
#   inflating: polyvore_outfits/images/90979114.jpg
#   inflating: polyvore_outfits/images/90981898.jpg
#   inflating: polyvore_outfits/images/90982653.jpg
#   inflating: polyvore_outfits/images/90987393.jpg
#   inflating: polyvore_outfits/images/90990016.jpg
#   inflating: polyvore_outfits/images/90994672.jpg
#   inflating: polyvore_outfits/images/91001298.jpg
#   inflating: polyvore_outfits/images/91005816.jpg
#   inflating: polyvore_outfits/images/91007671.jpg
#   inflating: polyvore_outfits/images/91010357.jpg
#   inflating: polyvore_outfits/images/91010405.jpg
#   inflating: polyvore_outfits/images/91010446.jpg
#   inflating: polyvore_outfits/images/91010633.jpg
#   inflating: polyvore_outfits/images/91010793.jpg
#   inflating: polyvore_outfits/images/91015133.jpg
#   inflating: polyvore_outfits/images/91016003.jpg
#   inflating: polyvore_outfits/images/91017318.jpg
#   inflating: polyvore_outfits/images/91017730.jpg
#   inflating: polyvore_outfits/images/91018872.jpg
#   inflating: polyvore_outfits/images/91021141.jpg
#   inflating: polyvore_outfits/images/91021338.jpg
#   inflating: polyvore_outfits/images/91021898.jpg
#   inflating: polyvore_outfits/images/91022274.jpg
#   inflating: polyvore_outfits/images/91022649.jpg
#   inflating: polyvore_outfits/images/91022891.jpg
#   inflating: polyvore_outfits/images/91023149.jpg
#   inflating: polyvore_outfits/images/91024356.jpg
#   inflating: polyvore_outfits/images/91025129.jpg
#   inflating: polyvore_outfits/images/91028336.jpg
#   inflating: polyvore_outfits/images/91034510.jpg
#   inflating: polyvore_outfits/images/91035726.jpg
#   inflating: polyvore_outfits/images/91035907.jpg
#   inflating: polyvore_outfits/images/91036691.jpg
#   inflating: polyvore_outfits/images/91036697.jpg
#   inflating: polyvore_outfits/images/91036704.jpg
#   inflating: polyvore_outfits/images/91055020.jpg
#   inflating: polyvore_outfits/images/91058392.jpg
#   inflating: polyvore_outfits/images/91067603.jpg
#   inflating: polyvore_outfits/images/91068392.jpg
#   inflating: polyvore_outfits/images/91070289.jpg
#   inflating: polyvore_outfits/images/91070411.jpg
#   inflating: polyvore_outfits/images/91070521.jpg
#   inflating: polyvore_outfits/images/91070671.jpg
#   inflating: polyvore_outfits/images/91080821.jpg
#   inflating: polyvore_outfits/images/91084676.jpg
#   inflating: polyvore_outfits/images/91085738.jpg
#   inflating: polyvore_outfits/images/91086606.jpg
#   inflating: polyvore_outfits/images/91086882.jpg
#   inflating: polyvore_outfits/images/91087305.jpg
#   inflating: polyvore_outfits/images/91088228.jpg
#   inflating: polyvore_outfits/images/91088758.jpg
#   inflating: polyvore_outfits/images/91089457.jpg
#   inflating: polyvore_outfits/images/91089593.jpg
#   inflating: polyvore_outfits/images/91090229.jpg
#   inflating: polyvore_outfits/images/91090509.jpg
#   inflating: polyvore_outfits/images/91090526.jpg
#   inflating: polyvore_outfits/images/91092119.jpg
#   inflating: polyvore_outfits/images/91093288.jpg
#   inflating: polyvore_outfits/images/91094306.jpg
#   inflating: polyvore_outfits/images/91094310.jpg
#   inflating: polyvore_outfits/images/91095607.jpg
#   inflating: polyvore_outfits/images/91098299.jpg
#   inflating: polyvore_outfits/images/91099540.jpg
#   inflating: polyvore_outfits/images/91103316.jpg
#   inflating: polyvore_outfits/images/91103334.jpg
#   inflating: polyvore_outfits/images/91104120.jpg
#   inflating: polyvore_outfits/images/91104276.jpg
#   inflating: polyvore_outfits/images/91106468.jpg
#   inflating: polyvore_outfits/images/91110398.jpg
#   inflating: polyvore_outfits/images/91116998.jpg
#   inflating: polyvore_outfits/images/91117000.jpg
#   inflating: polyvore_outfits/images/91117139.jpg
#   inflating: polyvore_outfits/images/91117163.jpg
#   inflating: polyvore_outfits/images/91118973.jpg
#   inflating: polyvore_outfits/images/91119029.jpg
#   inflating: polyvore_outfits/images/91124875.jpg
#   inflating: polyvore_outfits/images/91128912.jpg
#   inflating: polyvore_outfits/images/91129642.jpg
#   inflating: polyvore_outfits/images/91130206.jpg
#   inflating: polyvore_outfits/images/91136011.jpg
#   inflating: polyvore_outfits/images/91138962.jpg
#   inflating: polyvore_outfits/images/91139978.jpg
#   inflating: polyvore_outfits/images/91139990.jpg
#   inflating: polyvore_outfits/images/91141085.jpg
#   inflating: polyvore_outfits/images/91141101.jpg
#   inflating: polyvore_outfits/images/91141102.jpg
#   inflating: polyvore_outfits/images/91144637.jpg
#   inflating: polyvore_outfits/images/91146812.jpg
#   inflating: polyvore_outfits/images/91147512.jpg
#   inflating: polyvore_outfits/images/91147687.jpg
#   inflating: polyvore_outfits/images/91147689.jpg
#   inflating: polyvore_outfits/images/91147881.jpg
#   inflating: polyvore_outfits/images/91148317.jpg
#   inflating: polyvore_outfits/images/91148621.jpg
#   inflating: polyvore_outfits/images/91149152.jpg
#   inflating: polyvore_outfits/images/91149699.jpg
#   inflating: polyvore_outfits/images/91152057.jpg
#   inflating: polyvore_outfits/images/91152382.jpg
#   inflating: polyvore_outfits/images/91153928.jpg
#   inflating: polyvore_outfits/images/91155758.jpg
#   inflating: polyvore_outfits/images/91155802.jpg
#   inflating: polyvore_outfits/images/91156239.jpg
#   inflating: polyvore_outfits/images/91156759.jpg
#   inflating: polyvore_outfits/images/91157113.jpg
#   inflating: polyvore_outfits/images/91161099.jpg
#   inflating: polyvore_outfits/images/91161597.jpg
#   inflating: polyvore_outfits/images/91165401.jpg
#   inflating: polyvore_outfits/images/91165992.jpg
#   inflating: polyvore_outfits/images/91170233.jpg
#   inflating: polyvore_outfits/images/91170299.jpg
#   inflating: polyvore_outfits/images/91170827.jpg
#   inflating: polyvore_outfits/images/91171137.jpg
#   inflating: polyvore_outfits/images/91171992.jpg
#   inflating: polyvore_outfits/images/91172128.jpg
#   inflating: polyvore_outfits/images/91173744.jpg
#   inflating: polyvore_outfits/images/91174002.jpg
#   inflating: polyvore_outfits/images/91176549.jpg
#   inflating: polyvore_outfits/images/91177000.jpg
#   inflating: polyvore_outfits/images/91178542.jpg
#   inflating: polyvore_outfits/images/91178544.jpg
#   inflating: polyvore_outfits/images/91179671.jpg
#   inflating: polyvore_outfits/images/91180911.jpg
#   inflating: polyvore_outfits/images/91190571.jpg
#   inflating: polyvore_outfits/images/91191501.jpg
#   inflating: polyvore_outfits/images/91191798.jpg
#   inflating: polyvore_outfits/images/91193994.jpg
#   inflating: polyvore_outfits/images/91197511.jpg
#   inflating: polyvore_outfits/images/91197662.jpg
#   inflating: polyvore_outfits/images/91197686.jpg
#   inflating: polyvore_outfits/images/91197963.jpg
#   inflating: polyvore_outfits/images/91198444.jpg
#   inflating: polyvore_outfits/images/91199555.jpg
#   inflating: polyvore_outfits/images/91200130.jpg
#   inflating: polyvore_outfits/images/91201724.jpg
#   inflating: polyvore_outfits/images/91203153.jpg
#   inflating: polyvore_outfits/images/91206319.jpg
#   inflating: polyvore_outfits/images/91208999.jpg
#   inflating: polyvore_outfits/images/91209892.jpg
#   inflating: polyvore_outfits/images/91210256.jpg
#   inflating: polyvore_outfits/images/91214610.jpg
#   inflating: polyvore_outfits/images/91214747.jpg
#   inflating: polyvore_outfits/images/91215480.jpg
#   inflating: polyvore_outfits/images/91215543.jpg
#   inflating: polyvore_outfits/images/91216190.jpg
#   inflating: polyvore_outfits/images/91218982.jpg
#   inflating: polyvore_outfits/images/91222683.jpg
#   inflating: polyvore_outfits/images/91223400.jpg
#   inflating: polyvore_outfits/images/91223421.jpg
#   inflating: polyvore_outfits/images/91225505.jpg
#   inflating: polyvore_outfits/images/91226600.jpg
#   inflating: polyvore_outfits/images/91227581.jpg
#   inflating: polyvore_outfits/images/91227589.jpg
#   inflating: polyvore_outfits/images/91228024.jpg
#   inflating: polyvore_outfits/images/91229077.jpg
#   inflating: polyvore_outfits/images/91229532.jpg
#   inflating: polyvore_outfits/images/91231230.jpg
#   inflating: polyvore_outfits/images/91231643.jpg
#   inflating: polyvore_outfits/images/91233366.jpg
#   inflating: polyvore_outfits/images/91233749.jpg
#   inflating: polyvore_outfits/images/91234567.jpg
#   inflating: polyvore_outfits/images/91234837.jpg
#   inflating: polyvore_outfits/images/91237926.jpg
#   inflating: polyvore_outfits/images/91238060.jpg
#   inflating: polyvore_outfits/images/91238566.jpg
#   inflating: polyvore_outfits/images/91239030.jpg
#   inflating: polyvore_outfits/images/91241935.jpg
#   inflating: polyvore_outfits/images/91242948.jpg
#   inflating: polyvore_outfits/images/91243830.jpg
#   inflating: polyvore_outfits/images/91243964.jpg
#   inflating: polyvore_outfits/images/91250485.jpg
#   inflating: polyvore_outfits/images/91252683.jpg
#   inflating: polyvore_outfits/images/91253948.jpg
#   inflating: polyvore_outfits/images/91257363.jpg
#   inflating: polyvore_outfits/images/91260215.jpg
#   inflating: polyvore_outfits/images/91266520.jpg
#   inflating: polyvore_outfits/images/91270701.jpg
#   inflating: polyvore_outfits/images/91271606.jpg
#   inflating: polyvore_outfits/images/91271745.jpg
#   inflating: polyvore_outfits/images/91271944.jpg
#   inflating: polyvore_outfits/images/91271961.jpg
#   inflating: polyvore_outfits/images/91273608.jpg
#   inflating: polyvore_outfits/images/91276003.jpg
#   inflating: polyvore_outfits/images/91285259.jpg
#   inflating: polyvore_outfits/images/91288906.jpg
#   inflating: polyvore_outfits/images/91290111.jpg
#   inflating: polyvore_outfits/images/91295802.jpg
#   inflating: polyvore_outfits/images/91297914.jpg
#   inflating: polyvore_outfits/images/91299208.jpg
#   inflating: polyvore_outfits/images/91299730.jpg
#   inflating: polyvore_outfits/images/91300779.jpg
#   inflating: polyvore_outfits/images/91300964.jpg
#   inflating: polyvore_outfits/images/91303242.jpg
#   inflating: polyvore_outfits/images/91303889.jpg
#   inflating: polyvore_outfits/images/91306836.jpg
#   inflating: polyvore_outfits/images/91310518.jpg
#   inflating: polyvore_outfits/images/91310589.jpg
#   inflating: polyvore_outfits/images/91311404.jpg
#   inflating: polyvore_outfits/images/91311623.jpg
#   inflating: polyvore_outfits/images/91314033.jpg
#   inflating: polyvore_outfits/images/91316316.jpg
#   inflating: polyvore_outfits/images/91318516.jpg
#   inflating: polyvore_outfits/images/91319283.jpg
#   inflating: polyvore_outfits/images/91319293.jpg
#   inflating: polyvore_outfits/images/91319739.jpg
#   inflating: polyvore_outfits/images/91319923.jpg
#   inflating: polyvore_outfits/images/91321468.jpg
#   inflating: polyvore_outfits/images/91321970.jpg
#   inflating: polyvore_outfits/images/91322135.jpg
#   inflating: polyvore_outfits/images/91322183.jpg
#   inflating: polyvore_outfits/images/91322244.jpg
#   inflating: polyvore_outfits/images/91322662.jpg
#   inflating: polyvore_outfits/images/91322924.jpg
#   inflating: polyvore_outfits/images/91322948.jpg
#   inflating: polyvore_outfits/images/91330769.jpg
#   inflating: polyvore_outfits/images/91332891.jpg
#   inflating: polyvore_outfits/images/91333137.jpg
#   inflating: polyvore_outfits/images/91333529.jpg
#   inflating: polyvore_outfits/images/91333663.jpg
#   inflating: polyvore_outfits/images/91333694.jpg
#   inflating: polyvore_outfits/images/91336003.jpg
#   inflating: polyvore_outfits/images/91337883.jpg
#   inflating: polyvore_outfits/images/91338793.jpg
#   inflating: polyvore_outfits/images/91339290.jpg
#   inflating: polyvore_outfits/images/91340077.jpg
#   inflating: polyvore_outfits/images/91341059.jpg
#   inflating: polyvore_outfits/images/91341647.jpg
#   inflating: polyvore_outfits/images/91341903.jpg
#   inflating: polyvore_outfits/images/91342129.jpg
#   inflating: polyvore_outfits/images/91346778.jpg
#   inflating: polyvore_outfits/images/91354014.jpg
#   inflating: polyvore_outfits/images/91356396.jpg
#   inflating: polyvore_outfits/images/9135695.jpg
#   inflating: polyvore_outfits/images/91358652.jpg
#   inflating: polyvore_outfits/images/91358918.jpg
#   inflating: polyvore_outfits/images/91361543.jpg
#   inflating: polyvore_outfits/images/91361804.jpg
#   inflating: polyvore_outfits/images/91362066.jpg
#   inflating: polyvore_outfits/images/91365768.jpg
#   inflating: polyvore_outfits/images/91366130.jpg
#   inflating: polyvore_outfits/images/91366508.jpg
#   inflating: polyvore_outfits/images/91368201.jpg
#   inflating: polyvore_outfits/images/91368318.jpg
#   inflating: polyvore_outfits/images/91373529.jpg
#   inflating: polyvore_outfits/images/91374238.jpg
#   inflating: polyvore_outfits/images/91380331.jpg
#   inflating: polyvore_outfits/images/91381985.jpg
#   inflating: polyvore_outfits/images/91385240.jpg
#   inflating: polyvore_outfits/images/91385803.jpg
#   inflating: polyvore_outfits/images/91389309.jpg
#   inflating: polyvore_outfits/images/91392767.jpg
#   inflating: polyvore_outfits/images/91394907.jpg
#   inflating: polyvore_outfits/images/91400109.jpg
#   inflating: polyvore_outfits/images/91400138.jpg
#   inflating: polyvore_outfits/images/91401501.jpg
#   inflating: polyvore_outfits/images/91401700.jpg
#   inflating: polyvore_outfits/images/91405834.jpg
#   inflating: polyvore_outfits/images/91414645.jpg
#   inflating: polyvore_outfits/images/9141723.jpg
#   inflating: polyvore_outfits/images/91420145.jpg
#   inflating: polyvore_outfits/images/91421748.jpg
#   inflating: polyvore_outfits/images/91425555.jpg
#   inflating: polyvore_outfits/images/91426340.jpg
#   inflating: polyvore_outfits/images/91426786.jpg
#   inflating: polyvore_outfits/images/91427348.jpg
#   inflating: polyvore_outfits/images/91430718.jpg
#   inflating: polyvore_outfits/images/91437821.jpg
#   inflating: polyvore_outfits/images/91438849.jpg
#   inflating: polyvore_outfits/images/91438866.jpg
#   inflating: polyvore_outfits/images/91439053.jpg
#   inflating: polyvore_outfits/images/91444228.jpg
#   inflating: polyvore_outfits/images/91444247.jpg
#   inflating: polyvore_outfits/images/91445821.jpg
#   inflating: polyvore_outfits/images/9144975.jpg
#   inflating: polyvore_outfits/images/9145109.jpg
#   inflating: polyvore_outfits/images/91451711.jpg
#   inflating: polyvore_outfits/images/91456210.jpg
#   inflating: polyvore_outfits/images/91465043.jpg
#   inflating: polyvore_outfits/images/91474084.jpg
#   inflating: polyvore_outfits/images/91474720.jpg
#   inflating: polyvore_outfits/images/91475804.jpg
#   inflating: polyvore_outfits/images/91476042.jpg
#   inflating: polyvore_outfits/images/91477618.jpg
#   inflating: polyvore_outfits/images/91478360.jpg
#   inflating: polyvore_outfits/images/91482213.jpg
#   inflating: polyvore_outfits/images/91484610.jpg
#   inflating: polyvore_outfits/images/91489517.jpg
#   inflating: polyvore_outfits/images/91490145.jpg
#   inflating: polyvore_outfits/images/91494029.jpg
#   inflating: polyvore_outfits/images/91497277.jpg
#   inflating: polyvore_outfits/images/91499141.jpg
#   inflating: polyvore_outfits/images/91500866.jpg
#   inflating: polyvore_outfits/images/91504061.jpg
#   inflating: polyvore_outfits/images/91512314.jpg
#   inflating: polyvore_outfits/images/91519828.jpg
#   inflating: polyvore_outfits/images/91530136.jpg
#   inflating: polyvore_outfits/images/91530158.jpg
#   inflating: polyvore_outfits/images/91533128.jpg
#   inflating: polyvore_outfits/images/91533184.jpg
#   inflating: polyvore_outfits/images/91540754.jpg
#   inflating: polyvore_outfits/images/91542496.jpg
#   inflating: polyvore_outfits/images/91544393.jpg
#   inflating: polyvore_outfits/images/91544773.jpg
#   inflating: polyvore_outfits/images/9154553.jpg
#   inflating: polyvore_outfits/images/91548012.jpg
#   inflating: polyvore_outfits/images/91548961.jpg
#   inflating: polyvore_outfits/images/91550082.jpg
#   inflating: polyvore_outfits/images/91550085.jpg
#   inflating: polyvore_outfits/images/91550387.jpg
#   inflating: polyvore_outfits/images/91552496.jpg
#   inflating: polyvore_outfits/images/91567721.jpg
#   inflating: polyvore_outfits/images/91567833.jpg
#   inflating: polyvore_outfits/images/91575267.jpg
#   inflating: polyvore_outfits/images/91577138.jpg
#   inflating: polyvore_outfits/images/91579364.jpg
#   inflating: polyvore_outfits/images/91589446.jpg
#   inflating: polyvore_outfits/images/91590404.jpg
#   inflating: polyvore_outfits/images/91592246.jpg
#   inflating: polyvore_outfits/images/91594599.jpg
#   inflating: polyvore_outfits/images/91595512.jpg
#   inflating: polyvore_outfits/images/91595722.jpg
#   inflating: polyvore_outfits/images/91597787.jpg
#   inflating: polyvore_outfits/images/91600656.jpg
#   inflating: polyvore_outfits/images/91602427.jpg
#   inflating: polyvore_outfits/images/91602796.jpg
#   inflating: polyvore_outfits/images/91603940.jpg
#   inflating: polyvore_outfits/images/91605221.jpg
#   inflating: polyvore_outfits/images/91606486.jpg
#   inflating: polyvore_outfits/images/91611996.jpg
#   inflating: polyvore_outfits/images/91613499.jpg
#   inflating: polyvore_outfits/images/91615758.jpg
#   inflating: polyvore_outfits/images/91617389.jpg
#   inflating: polyvore_outfits/images/91617535.jpg
#   inflating: polyvore_outfits/images/91620756.jpg
#   inflating: polyvore_outfits/images/91621278.jpg
#   inflating: polyvore_outfits/images/91621967.jpg
#   inflating: polyvore_outfits/images/91622879.jpg
#   inflating: polyvore_outfits/images/91623696.jpg
#   inflating: polyvore_outfits/images/91624495.jpg
#   inflating: polyvore_outfits/images/91624894.jpg
#   inflating: polyvore_outfits/images/91624976.jpg
#   inflating: polyvore_outfits/images/91630183.jpg
#   inflating: polyvore_outfits/images/91630458.jpg
#   inflating: polyvore_outfits/images/91630934.jpg
#   inflating: polyvore_outfits/images/91631259.jpg
#   inflating: polyvore_outfits/images/91631924.jpg
#   inflating: polyvore_outfits/images/91632635.jpg
#   inflating: polyvore_outfits/images/91633842.jpg
#   inflating: polyvore_outfits/images/91634408.jpg
#   inflating: polyvore_outfits/images/91634674.jpg
#   inflating: polyvore_outfits/images/91637906.jpg
#   inflating: polyvore_outfits/images/91641607.jpg
#   inflating: polyvore_outfits/images/91643871.jpg
#   inflating: polyvore_outfits/images/91645079.jpg
#   inflating: polyvore_outfits/images/91651733.jpg
#   inflating: polyvore_outfits/images/91654421.jpg
#   inflating: polyvore_outfits/images/91655818.jpg
#   inflating: polyvore_outfits/images/91655871.jpg
#   inflating: polyvore_outfits/images/91659934.jpg
#   inflating: polyvore_outfits/images/91662155.jpg
#   inflating: polyvore_outfits/images/91663113.jpg
#   inflating: polyvore_outfits/images/91667305.jpg
#   inflating: polyvore_outfits/images/91667307.jpg
#   inflating: polyvore_outfits/images/91673120.jpg
#   inflating: polyvore_outfits/images/91676647.jpg
#   inflating: polyvore_outfits/images/91677446.jpg
#   inflating: polyvore_outfits/images/91679824.jpg
#   inflating: polyvore_outfits/images/91683660.jpg
#   inflating: polyvore_outfits/images/91684511.jpg
#   inflating: polyvore_outfits/images/91688559.jpg
#   inflating: polyvore_outfits/images/91688896.jpg
#   inflating: polyvore_outfits/images/91689509.jpg
#   inflating: polyvore_outfits/images/91690080.jpg
#   inflating: polyvore_outfits/images/91692863.jpg
#   inflating: polyvore_outfits/images/91693042.jpg
#   inflating: polyvore_outfits/images/91693242.jpg
#   inflating: polyvore_outfits/images/91693625.jpg
#   inflating: polyvore_outfits/images/91694327.jpg
#   inflating: polyvore_outfits/images/91694720.jpg
#   inflating: polyvore_outfits/images/91696483.jpg
#   inflating: polyvore_outfits/images/91697050.jpg
#   inflating: polyvore_outfits/images/91698063.jpg
#   inflating: polyvore_outfits/images/91698126.jpg
#   inflating: polyvore_outfits/images/91700088.jpg
#   inflating: polyvore_outfits/images/91703312.jpg
#   inflating: polyvore_outfits/images/91703371.jpg
#   inflating: polyvore_outfits/images/91703540.jpg
#   inflating: polyvore_outfits/images/91704352.jpg
#   inflating: polyvore_outfits/images/91704501.jpg
#   inflating: polyvore_outfits/images/91707346.jpg
#   inflating: polyvore_outfits/images/91710882.jpg
#   inflating: polyvore_outfits/images/91711136.jpg
#   inflating: polyvore_outfits/images/91712070.jpg
#   inflating: polyvore_outfits/images/91726389.jpg
#   inflating: polyvore_outfits/images/91730888.jpg
#   inflating: polyvore_outfits/images/91734071.jpg
#   inflating: polyvore_outfits/images/91734752.jpg
#   inflating: polyvore_outfits/images/91735564.jpg
#   inflating: polyvore_outfits/images/91737188.jpg
#   inflating: polyvore_outfits/images/91740329.jpg
#   inflating: polyvore_outfits/images/91740759.jpg
#   inflating: polyvore_outfits/images/91741791.jpg
#   inflating: polyvore_outfits/images/91742695.jpg
#   inflating: polyvore_outfits/images/91747177.jpg
#   inflating: polyvore_outfits/images/91747798.jpg
#   inflating: polyvore_outfits/images/91749339.jpg
#   inflating: polyvore_outfits/images/91749355.jpg
#   inflating: polyvore_outfits/images/91750056.jpg
#   inflating: polyvore_outfits/images/91752833.jpg
#   inflating: polyvore_outfits/images/91753370.jpg
#   inflating: polyvore_outfits/images/91757323.jpg
#   inflating: polyvore_outfits/images/91763140.jpg
#   inflating: polyvore_outfits/images/91765138.jpg
#   inflating: polyvore_outfits/images/91766470.jpg
#   inflating: polyvore_outfits/images/91766900.jpg
#   inflating: polyvore_outfits/images/91771269.jpg
#   inflating: polyvore_outfits/images/91772241.jpg
#   inflating: polyvore_outfits/images/91776089.jpg
#   inflating: polyvore_outfits/images/91776798.jpg
#   inflating: polyvore_outfits/images/91776893.jpg
#   inflating: polyvore_outfits/images/91777190.jpg
#   inflating: polyvore_outfits/images/91777432.jpg
#   inflating: polyvore_outfits/images/91777639.jpg
#   inflating: polyvore_outfits/images/91780255.jpg
#   inflating: polyvore_outfits/images/91781047.jpg
#   inflating: polyvore_outfits/images/91782923.jpg
#   inflating: polyvore_outfits/images/91784764.jpg
#   inflating: polyvore_outfits/images/91792645.jpg
#   inflating: polyvore_outfits/images/91794177.jpg
#   inflating: polyvore_outfits/images/91797477.jpg
#   inflating: polyvore_outfits/images/91800549.jpg
#   inflating: polyvore_outfits/images/91803790.jpg
#   inflating: polyvore_outfits/images/91810020.jpg
#   inflating: polyvore_outfits/images/91810579.jpg
#   inflating: polyvore_outfits/images/91810598.jpg
#   inflating: polyvore_outfits/images/91810728.jpg
#   inflating: polyvore_outfits/images/91813147.jpg
#   inflating: polyvore_outfits/images/91814352.jpg
#   inflating: polyvore_outfits/images/91814896.jpg
#   inflating: polyvore_outfits/images/91815559.jpg
#   inflating: polyvore_outfits/images/91815604.jpg
#   inflating: polyvore_outfits/images/91815799.jpg
#   inflating: polyvore_outfits/images/91815808.jpg
#   inflating: polyvore_outfits/images/91819666.jpg
#   inflating: polyvore_outfits/images/91819675.jpg
#   inflating: polyvore_outfits/images/91820209.jpg
#   inflating: polyvore_outfits/images/91821978.jpg
#   inflating: polyvore_outfits/images/91822269.jpg
#   inflating: polyvore_outfits/images/91823364.jpg
#   inflating: polyvore_outfits/images/91825220.jpg
#   inflating: polyvore_outfits/images/91825284.jpg
#   inflating: polyvore_outfits/images/91826001.jpg
#   inflating: polyvore_outfits/images/91826266.jpg
#   inflating: polyvore_outfits/images/91829997.jpg
#   inflating: polyvore_outfits/images/91831153.jpg
#   inflating: polyvore_outfits/images/91831649.jpg
#   inflating: polyvore_outfits/images/91832888.jpg
#   inflating: polyvore_outfits/images/91833571.jpg
#   inflating: polyvore_outfits/images/91833600.jpg
#   inflating: polyvore_outfits/images/91835393.jpg
#   inflating: polyvore_outfits/images/91836848.jpg
#   inflating: polyvore_outfits/images/91836900.jpg
#   inflating: polyvore_outfits/images/91838788.jpg
#   inflating: polyvore_outfits/images/91838898.jpg
#   inflating: polyvore_outfits/images/91841612.jpg
#   inflating: polyvore_outfits/images/91842832.jpg
#   inflating: polyvore_outfits/images/91850397.jpg
#   inflating: polyvore_outfits/images/91864034.jpg
#   inflating: polyvore_outfits/images/91866340.jpg
#   inflating: polyvore_outfits/images/91866866.jpg
#   inflating: polyvore_outfits/images/91872063.jpg
#   inflating: polyvore_outfits/images/91880379.jpg
#   inflating: polyvore_outfits/images/91884391.jpg
#   inflating: polyvore_outfits/images/91887055.jpg
#   inflating: polyvore_outfits/images/91890735.jpg
#   inflating: polyvore_outfits/images/91891144.jpg
#   inflating: polyvore_outfits/images/91892385.jpg
#   inflating: polyvore_outfits/images/91892392.jpg
#   inflating: polyvore_outfits/images/91894524.jpg
#   inflating: polyvore_outfits/images/91896161.jpg
#   inflating: polyvore_outfits/images/91896163.jpg
#   inflating: polyvore_outfits/images/91898133.jpg
#   inflating: polyvore_outfits/images/91898306.jpg
#   inflating: polyvore_outfits/images/91898606.jpg
#   inflating: polyvore_outfits/images/91900429.jpg
#   inflating: polyvore_outfits/images/91903223.jpg
#   inflating: polyvore_outfits/images/91903824.jpg
#   inflating: polyvore_outfits/images/91904500.jpg
#   inflating: polyvore_outfits/images/91905622.jpg
#   inflating: polyvore_outfits/images/91910979.jpg
#   inflating: polyvore_outfits/images/91914918.jpg
#   inflating: polyvore_outfits/images/91915132.jpg
#   inflating: polyvore_outfits/images/91922866.jpg
#   inflating: polyvore_outfits/images/91923873.jpg
#   inflating: polyvore_outfits/images/91924407.jpg
#   inflating: polyvore_outfits/images/91924731.jpg
#   inflating: polyvore_outfits/images/91926484.jpg
#   inflating: polyvore_outfits/images/91934901.jpg
#   inflating: polyvore_outfits/images/91935663.jpg
#   inflating: polyvore_outfits/images/91938131.jpg
#   inflating: polyvore_outfits/images/91939703.jpg
#   inflating: polyvore_outfits/images/91942216.jpg
#   inflating: polyvore_outfits/images/91942219.jpg
#   inflating: polyvore_outfits/images/91942518.jpg
#   inflating: polyvore_outfits/images/91943387.jpg
#   inflating: polyvore_outfits/images/91944375.jpg
#   inflating: polyvore_outfits/images/91946795.jpg
#   inflating: polyvore_outfits/images/91948193.jpg
#   inflating: polyvore_outfits/images/91948241.jpg
#   inflating: polyvore_outfits/images/91950259.jpg
#   inflating: polyvore_outfits/images/91953782.jpg
#   inflating: polyvore_outfits/images/91974100.jpg
#   inflating: polyvore_outfits/images/91978823.jpg
#   inflating: polyvore_outfits/images/91981889.jpg
#   inflating: polyvore_outfits/images/91985578.jpg
#   inflating: polyvore_outfits/images/91985614.jpg
#   inflating: polyvore_outfits/images/91987231.jpg
#   inflating: polyvore_outfits/images/91995566.jpg
#   inflating: polyvore_outfits/images/91997537.jpg
#   inflating: polyvore_outfits/images/92001082.jpg
#   inflating: polyvore_outfits/images/92003384.jpg
#   inflating: polyvore_outfits/images/92007868.jpg
#   inflating: polyvore_outfits/images/92007985.jpg
#   inflating: polyvore_outfits/images/92009215.jpg
#   inflating: polyvore_outfits/images/92012277.jpg
#   inflating: polyvore_outfits/images/92017489.jpg
#   inflating: polyvore_outfits/images/92019154.jpg
#   inflating: polyvore_outfits/images/9202240.jpg
#   inflating: polyvore_outfits/images/92022603.jpg
#   inflating: polyvore_outfits/images/92024012.jpg
#   inflating: polyvore_outfits/images/92027518.jpg
#   inflating: polyvore_outfits/images/9202904.jpg
#   inflating: polyvore_outfits/images/9203579.jpg
#   inflating: polyvore_outfits/images/92042978.jpg
#   inflating: polyvore_outfits/images/92043738.jpg
#   inflating: polyvore_outfits/images/92045858.jpg
#   inflating: polyvore_outfits/images/92052306.jpg
#   inflating: polyvore_outfits/images/92052566.jpg
#   inflating: polyvore_outfits/images/92054614.jpg
#   inflating: polyvore_outfits/images/92057765.jpg
#   inflating: polyvore_outfits/images/92057908.jpg
#   inflating: polyvore_outfits/images/92063991.jpg
#   inflating: polyvore_outfits/images/92064259.jpg
#   inflating: polyvore_outfits/images/92065369.jpg
#   inflating: polyvore_outfits/images/92081171.jpg
#   inflating: polyvore_outfits/images/92084094.jpg
#   inflating: polyvore_outfits/images/92091482.jpg
#   inflating: polyvore_outfits/images/92091698.jpg
#   inflating: polyvore_outfits/images/92094621.jpg
#   inflating: polyvore_outfits/images/92094632.jpg
#   inflating: polyvore_outfits/images/92094707.jpg
#   inflating: polyvore_outfits/images/92098208.jpg
#   inflating: polyvore_outfits/images/92116141.jpg
#   inflating: polyvore_outfits/images/92117377.jpg
#   inflating: polyvore_outfits/images/92119512.jpg
#   inflating: polyvore_outfits/images/92120263.jpg
#   inflating: polyvore_outfits/images/92121192.jpg
#   inflating: polyvore_outfits/images/92122141.jpg
#   inflating: polyvore_outfits/images/92123125.jpg
#   inflating: polyvore_outfits/images/92123853.jpg
#   inflating: polyvore_outfits/images/92124335.jpg
#   inflating: polyvore_outfits/images/92128256.jpg
#   inflating: polyvore_outfits/images/92128284.jpg
#   inflating: polyvore_outfits/images/92128457.jpg
#   inflating: polyvore_outfits/images/92128510.jpg
#   inflating: polyvore_outfits/images/92136723.jpg
#   inflating: polyvore_outfits/images/92137094.jpg
#   inflating: polyvore_outfits/images/92137674.jpg
#   inflating: polyvore_outfits/images/92138655.jpg
#   inflating: polyvore_outfits/images/92138661.jpg
#   inflating: polyvore_outfits/images/92138691.jpg
#   inflating: polyvore_outfits/images/92138738.jpg
#   inflating: polyvore_outfits/images/92140550.jpg
#   inflating: polyvore_outfits/images/92142762.jpg
#   inflating: polyvore_outfits/images/92146956.jpg
#   inflating: polyvore_outfits/images/92147091.jpg
#   inflating: polyvore_outfits/images/92152131.jpg
#   inflating: polyvore_outfits/images/92152561.jpg
#   inflating: polyvore_outfits/images/92153950.jpg
#   inflating: polyvore_outfits/images/92154112.jpg
#   inflating: polyvore_outfits/images/92154201.jpg
#   inflating: polyvore_outfits/images/92155057.jpg
#   inflating: polyvore_outfits/images/92163083.jpg
#   inflating: polyvore_outfits/images/92166860.jpg
#   inflating: polyvore_outfits/images/92178982.jpg
#   inflating: polyvore_outfits/images/92179146.jpg
#   inflating: polyvore_outfits/images/92180990.jpg
#   inflating: polyvore_outfits/images/92181468.jpg
#   inflating: polyvore_outfits/images/92182928.jpg
#   inflating: polyvore_outfits/images/92182973.jpg
#   inflating: polyvore_outfits/images/92183195.jpg
#   inflating: polyvore_outfits/images/92183467.jpg
#   inflating: polyvore_outfits/images/92183573.jpg
#   inflating: polyvore_outfits/images/92183743.jpg
#   inflating: polyvore_outfits/images/92183812.jpg
#   inflating: polyvore_outfits/images/92184381.jpg
#   inflating: polyvore_outfits/images/92187524.jpg
#   inflating: polyvore_outfits/images/92189320.jpg
#   inflating: polyvore_outfits/images/92189436.jpg
#   inflating: polyvore_outfits/images/92189730.jpg
#   inflating: polyvore_outfits/images/92189933.jpg
#   inflating: polyvore_outfits/images/92190015.jpg
#   inflating: polyvore_outfits/images/92190036.jpg
#   inflating: polyvore_outfits/images/92198921.jpg
#   inflating: polyvore_outfits/images/92199312.jpg
#   inflating: polyvore_outfits/images/92201464.jpg
#   inflating: polyvore_outfits/images/92201482.jpg
#   inflating: polyvore_outfits/images/92201867.jpg
#   inflating: polyvore_outfits/images/92202289.jpg
#   inflating: polyvore_outfits/images/92203246.jpg
#   inflating: polyvore_outfits/images/92203347.jpg
#   inflating: polyvore_outfits/images/92203414.jpg
#   inflating: polyvore_outfits/images/92203730.jpg
#   inflating: polyvore_outfits/images/92205757.jpg
#   inflating: polyvore_outfits/images/92207642.jpg
#   inflating: polyvore_outfits/images/92208067.jpg
#   inflating: polyvore_outfits/images/92209648.jpg
#   inflating: polyvore_outfits/images/92211022.jpg
#   inflating: polyvore_outfits/images/92211777.jpg
#   inflating: polyvore_outfits/images/92216580.jpg
#   inflating: polyvore_outfits/images/92217796.jpg
#   inflating: polyvore_outfits/images/92218419.jpg
#   inflating: polyvore_outfits/images/92219449.jpg
#   inflating: polyvore_outfits/images/92219854.jpg
#   inflating: polyvore_outfits/images/92220190.jpg
#   inflating: polyvore_outfits/images/92220302.jpg
#   inflating: polyvore_outfits/images/92220608.jpg
#   inflating: polyvore_outfits/images/92221802.jpg
#   inflating: polyvore_outfits/images/92223346.jpg
#   inflating: polyvore_outfits/images/92224528.jpg
#   inflating: polyvore_outfits/images/9223168.jpg
#   inflating: polyvore_outfits/images/92236986.jpg
#   inflating: polyvore_outfits/images/92237783.jpg
#   inflating: polyvore_outfits/images/92238323.jpg
#   inflating: polyvore_outfits/images/92238933.jpg
#   inflating: polyvore_outfits/images/92239015.jpg
#   inflating: polyvore_outfits/images/92240295.jpg
#   inflating: polyvore_outfits/images/92243392.jpg
#   inflating: polyvore_outfits/images/92243723.jpg
#   inflating: polyvore_outfits/images/92244629.jpg
#   inflating: polyvore_outfits/images/92244654.jpg
#   inflating: polyvore_outfits/images/92244699.jpg
#   inflating: polyvore_outfits/images/92245591.jpg
#   inflating: polyvore_outfits/images/9224574.jpg
#   inflating: polyvore_outfits/images/92247640.jpg
#   inflating: polyvore_outfits/images/92256586.jpg
#   inflating: polyvore_outfits/images/92256878.jpg
#   inflating: polyvore_outfits/images/92257566.jpg
#   inflating: polyvore_outfits/images/92258495.jpg
#   inflating: polyvore_outfits/images/92258718.jpg
#   inflating: polyvore_outfits/images/92263707.jpg
#   inflating: polyvore_outfits/images/92272344.jpg
#   inflating: polyvore_outfits/images/92273591.jpg
#   inflating: polyvore_outfits/images/92274401.jpg
#   inflating: polyvore_outfits/images/92275877.jpg
#   inflating: polyvore_outfits/images/92278067.jpg
#   inflating: polyvore_outfits/images/92279728.jpg
#   inflating: polyvore_outfits/images/92280923.jpg
#   inflating: polyvore_outfits/images/92281963.jpg
#   inflating: polyvore_outfits/images/92283366.jpg
#   inflating: polyvore_outfits/images/92285720.jpg
#   inflating: polyvore_outfits/images/92289067.jpg
#   inflating: polyvore_outfits/images/92289630.jpg
#   inflating: polyvore_outfits/images/92289683.jpg
#   inflating: polyvore_outfits/images/92289722.jpg
#   inflating: polyvore_outfits/images/92290857.jpg
#   inflating: polyvore_outfits/images/92291190.jpg
#   inflating: polyvore_outfits/images/92292097.jpg
#   inflating: polyvore_outfits/images/92292722.jpg
#   inflating: polyvore_outfits/images/92292884.jpg
#   inflating: polyvore_outfits/images/92296244.jpg
#   inflating: polyvore_outfits/images/92298435.jpg
#   inflating: polyvore_outfits/images/92298632.jpg
#   inflating: polyvore_outfits/images/92299975.jpg
#   inflating: polyvore_outfits/images/92300788.jpg
#   inflating: polyvore_outfits/images/92303325.jpg
#   inflating: polyvore_outfits/images/92303351.jpg
#   inflating: polyvore_outfits/images/92303625.jpg
#   inflating: polyvore_outfits/images/92304302.jpg
#   inflating: polyvore_outfits/images/92304326.jpg
#   inflating: polyvore_outfits/images/92306012.jpg
#   inflating: polyvore_outfits/images/92306753.jpg
#   inflating: polyvore_outfits/images/92307165.jpg
#   inflating: polyvore_outfits/images/92307658.jpg
#   inflating: polyvore_outfits/images/92308386.jpg
#   inflating: polyvore_outfits/images/92309560.jpg
#   inflating: polyvore_outfits/images/92310593.jpg
#   inflating: polyvore_outfits/images/92310785.jpg
#   inflating: polyvore_outfits/images/92314580.jpg
#   inflating: polyvore_outfits/images/92315428.jpg
#   inflating: polyvore_outfits/images/92316505.jpg
#   inflating: polyvore_outfits/images/92317817.jpg
#   inflating: polyvore_outfits/images/92317821.jpg
#   inflating: polyvore_outfits/images/92321704.jpg
#   inflating: polyvore_outfits/images/92322353.jpg
#   inflating: polyvore_outfits/images/92323317.jpg
#   inflating: polyvore_outfits/images/92323430.jpg
#   inflating: polyvore_outfits/images/92330320.jpg
#   inflating: polyvore_outfits/images/92332876.jpg
#   inflating: polyvore_outfits/images/92333004.jpg
#   inflating: polyvore_outfits/images/92333460.jpg
#   inflating: polyvore_outfits/images/92333549.jpg
#   inflating: polyvore_outfits/images/92333928.jpg
#   inflating: polyvore_outfits/images/92334447.jpg
#   inflating: polyvore_outfits/images/92336673.jpg
#   inflating: polyvore_outfits/images/92336691.jpg
#   inflating: polyvore_outfits/images/92337672.jpg
#   inflating: polyvore_outfits/images/92338185.jpg
#   inflating: polyvore_outfits/images/92340830.jpg
#   inflating: polyvore_outfits/images/92340870.jpg
#   inflating: polyvore_outfits/images/92341043.jpg
#   inflating: polyvore_outfits/images/92341046.jpg
# ...
#   inflating: polyvore_outfits/images/99607202.jpg
#   inflating: polyvore_outfits/images/99607212.jpg
#   inflating: polyvore_outfits/images/99607276.jpg
#   inflating: polyvore_outfits/images/99608006.jpg
#   inflating: polyvore_outfits/images/99608605.jpg
#   inflating: polyvore_outfits/images/99611357.jpg
#   inflating: polyvore_outfits/images/99611787.jpg
#   inflating: polyvore_outfits/images/99614682.jpg
#   inflating: polyvore_outfits/images/99615930.jpg
#   inflating: polyvore_outfits/images/99616074.jpg
#   inflating: polyvore_outfits/images/99616202.jpg
#   inflating: polyvore_outfits/images/99616505.jpg
#   inflating: polyvore_outfits/images/99616670.jpg
#   inflating: polyvore_outfits/images/99616762.jpg
#   inflating: polyvore_outfits/images/99619122.jpg
#   inflating: polyvore_outfits/images/99619299.jpg
#   inflating: polyvore_outfits/images/99619512.jpg
#   inflating: polyvore_outfits/images/99620134.jpg
#   inflating: polyvore_outfits/images/99621687.jpg
#   inflating: polyvore_outfits/images/99622932.jpg
#   inflating: polyvore_outfits/images/99623253.jpg
#   inflating: polyvore_outfits/images/99623524.jpg
#   inflating: polyvore_outfits/images/99624238.jpg
#   inflating: polyvore_outfits/images/99624547.jpg
#   inflating: polyvore_outfits/images/99626208.jpg
#   inflating: polyvore_outfits/images/99626407.jpg
#   inflating: polyvore_outfits/images/99627749.jpg
#   inflating: polyvore_outfits/images/99627919.jpg
#   inflating: polyvore_outfits/images/99627982.jpg
#   inflating: polyvore_outfits/images/99628084.jpg
#   inflating: polyvore_outfits/images/99628160.jpg
#   inflating: polyvore_outfits/images/99628271.jpg
#   inflating: polyvore_outfits/images/99628404.jpg
#   inflating: polyvore_outfits/images/99630747.jpg
#   inflating: polyvore_outfits/images/99632619.jpg
#   inflating: polyvore_outfits/images/99632635.jpg
#   inflating: polyvore_outfits/images/99634017.jpg
#   inflating: polyvore_outfits/images/99639476.jpg
#   inflating: polyvore_outfits/images/99643175.jpg
#   inflating: polyvore_outfits/images/99645029.jpg
#   inflating: polyvore_outfits/images/99651009.jpg
#   inflating: polyvore_outfits/images/99651012.jpg
#   inflating: polyvore_outfits/images/99651053.jpg
#   inflating: polyvore_outfits/images/99651297.jpg
#   inflating: polyvore_outfits/images/99653723.jpg
#   inflating: polyvore_outfits/images/99654690.jpg
#   inflating: polyvore_outfits/images/99658889.jpg
#   inflating: polyvore_outfits/images/99660188.jpg
#   inflating: polyvore_outfits/images/99660360.jpg
#   inflating: polyvore_outfits/images/99660657.jpg
#   inflating: polyvore_outfits/images/99661244.jpg
#   inflating: polyvore_outfits/images/99661555.jpg
#   inflating: polyvore_outfits/images/99661717.jpg
#   inflating: polyvore_outfits/images/99662471.jpg
#   inflating: polyvore_outfits/images/99669512.jpg
#   inflating: polyvore_outfits/images/99669547.jpg
#   inflating: polyvore_outfits/images/99672147.jpg
#   inflating: polyvore_outfits/images/99672620.jpg
#   inflating: polyvore_outfits/images/99672792.jpg
#   inflating: polyvore_outfits/images/99672831.jpg
#   inflating: polyvore_outfits/images/99673751.jpg
#   inflating: polyvore_outfits/images/99675333.jpg
#   inflating: polyvore_outfits/images/99680356.jpg
#   inflating: polyvore_outfits/images/99681203.jpg
#   inflating: polyvore_outfits/images/99682140.jpg
#   inflating: polyvore_outfits/images/99682509.jpg
#   inflating: polyvore_outfits/images/99682702.jpg
#   inflating: polyvore_outfits/images/99683203.jpg
#   inflating: polyvore_outfits/images/99683438.jpg
#   inflating: polyvore_outfits/images/99684344.jpg
#   inflating: polyvore_outfits/images/99685702.jpg
#   inflating: polyvore_outfits/images/99685781.jpg
#   inflating: polyvore_outfits/images/99685859.jpg
#   inflating: polyvore_outfits/images/99685918.jpg
#   inflating: polyvore_outfits/images/99686696.jpg
#   inflating: polyvore_outfits/images/99687421.jpg
#   inflating: polyvore_outfits/images/99687449.jpg
#   inflating: polyvore_outfits/images/99687713.jpg
#   inflating: polyvore_outfits/images/99688916.jpg
#   inflating: polyvore_outfits/images/99689296.jpg
#   inflating: polyvore_outfits/images/99689774.jpg
#   inflating: polyvore_outfits/images/99689946.jpg
#   inflating: polyvore_outfits/images/99690116.jpg
#   inflating: polyvore_outfits/images/99690331.jpg
#   inflating: polyvore_outfits/images/99690907.jpg
#   inflating: polyvore_outfits/images/99691309.jpg
#   inflating: polyvore_outfits/images/99691599.jpg
#   inflating: polyvore_outfits/images/99692412.jpg
#   inflating: polyvore_outfits/images/9969260.jpg
#   inflating: polyvore_outfits/images/99694081.jpg
#   inflating: polyvore_outfits/images/99696734.jpg
#   inflating: polyvore_outfits/images/99696874.jpg
#   inflating: polyvore_outfits/images/99697291.jpg
#   inflating: polyvore_outfits/images/99699010.jpg
#   inflating: polyvore_outfits/images/99699024.jpg
#   inflating: polyvore_outfits/images/99699218.jpg
#   inflating: polyvore_outfits/images/99701811.jpg
#   inflating: polyvore_outfits/images/99705266.jpg
#   inflating: polyvore_outfits/images/99708147.jpg
#   inflating: polyvore_outfits/images/99711750.jpg
#   inflating: polyvore_outfits/images/99712372.jpg
#   inflating: polyvore_outfits/images/99713781.jpg
#   inflating: polyvore_outfits/images/99715094.jpg
#   inflating: polyvore_outfits/images/99716492.jpg
#   inflating: polyvore_outfits/images/99717053.jpg
#   inflating: polyvore_outfits/images/99717055.jpg
#   inflating: polyvore_outfits/images/99717427.jpg
#   inflating: polyvore_outfits/images/99719404.jpg
#   inflating: polyvore_outfits/images/99719602.jpg
#   inflating: polyvore_outfits/images/99720046.jpg
#   inflating: polyvore_outfits/images/99720576.jpg
#   inflating: polyvore_outfits/images/99723323.jpg
#   inflating: polyvore_outfits/images/99730623.jpg
#   inflating: polyvore_outfits/images/99732006.jpg
#   inflating: polyvore_outfits/images/99732607.jpg
#   inflating: polyvore_outfits/images/99733021.jpg
#   inflating: polyvore_outfits/images/99734611.jpg
#   inflating: polyvore_outfits/images/99744687.jpg
#   inflating: polyvore_outfits/images/99745777.jpg
#   inflating: polyvore_outfits/images/99745855.jpg
#   inflating: polyvore_outfits/images/99745919.jpg
#   inflating: polyvore_outfits/images/99746583.jpg
#   inflating: polyvore_outfits/images/99746700.jpg
#   inflating: polyvore_outfits/images/99747865.jpg
#   inflating: polyvore_outfits/images/99748152.jpg
#   inflating: polyvore_outfits/images/99748548.jpg
#   inflating: polyvore_outfits/images/99748628.jpg
#   inflating: polyvore_outfits/images/99749074.jpg
#   inflating: polyvore_outfits/images/99749465.jpg
#   inflating: polyvore_outfits/images/99750205.jpg
#   inflating: polyvore_outfits/images/99752503.jpg
#   inflating: polyvore_outfits/images/99752784.jpg
#   inflating: polyvore_outfits/images/99752832.jpg
#   inflating: polyvore_outfits/images/99753126.jpg
#   inflating: polyvore_outfits/images/99753472.jpg
#   inflating: polyvore_outfits/images/99753627.jpg
#   inflating: polyvore_outfits/images/99755339.jpg
#   inflating: polyvore_outfits/images/99755491.jpg
#   inflating: polyvore_outfits/images/99756263.jpg
#   inflating: polyvore_outfits/images/99756291.jpg
#   inflating: polyvore_outfits/images/99756721.jpg
#   inflating: polyvore_outfits/images/99757411.jpg
#   inflating: polyvore_outfits/images/99763727.jpg
#   inflating: polyvore_outfits/images/99764768.jpg
#   inflating: polyvore_outfits/images/99771258.jpg
#   inflating: polyvore_outfits/images/99773115.jpg
#   inflating: polyvore_outfits/images/99774368.jpg
#   inflating: polyvore_outfits/images/99774498.jpg
#   inflating: polyvore_outfits/images/99776051.jpg
#   inflating: polyvore_outfits/images/99779104.jpg
#   inflating: polyvore_outfits/images/99784968.jpg
#   inflating: polyvore_outfits/images/99792048.jpg
#   inflating: polyvore_outfits/images/99792204.jpg
#   inflating: polyvore_outfits/images/99793974.jpg
#   inflating: polyvore_outfits/images/99796686.jpg
#   inflating: polyvore_outfits/images/99797655.jpg
#   inflating: polyvore_outfits/images/99798516.jpg
#   inflating: polyvore_outfits/images/99798709.jpg
#   inflating: polyvore_outfits/images/99799807.jpg
#   inflating: polyvore_outfits/images/99802354.jpg
#   inflating: polyvore_outfits/images/99803551.jpg
#   inflating: polyvore_outfits/images/99807618.jpg
#   inflating: polyvore_outfits/images/99811600.jpg
#   inflating: polyvore_outfits/images/99812202.jpg
#   inflating: polyvore_outfits/images/99812279.jpg
#   inflating: polyvore_outfits/images/99813208.jpg
#   inflating: polyvore_outfits/images/99813649.jpg
#   inflating: polyvore_outfits/images/99814047.jpg
#   inflating: polyvore_outfits/images/99814995.jpg
#   inflating: polyvore_outfits/images/99816295.jpg
#   inflating: polyvore_outfits/images/99818988.jpg
#   inflating: polyvore_outfits/images/99819187.jpg
#   inflating: polyvore_outfits/images/99820823.jpg
#   inflating: polyvore_outfits/images/99822618.jpg
#   inflating: polyvore_outfits/images/99824538.jpg
#   inflating: polyvore_outfits/images/99828386.jpg
#   inflating: polyvore_outfits/images/99830720.jpg
#   inflating: polyvore_outfits/images/99832629.jpg
#   inflating: polyvore_outfits/images/99833967.jpg
#   inflating: polyvore_outfits/images/99835256.jpg
#   inflating: polyvore_outfits/images/99836787.jpg
#   inflating: polyvore_outfits/images/99839133.jpg
#   inflating: polyvore_outfits/images/99840061.jpg
#   inflating: polyvore_outfits/images/99844730.jpg
#   inflating: polyvore_outfits/images/99847667.jpg
#   inflating: polyvore_outfits/images/99847828.jpg
#   inflating: polyvore_outfits/images/99848072.jpg
#   inflating: polyvore_outfits/images/99853799.jpg
#   inflating: polyvore_outfits/images/99855212.jpg
#   inflating: polyvore_outfits/images/99856655.jpg
#   inflating: polyvore_outfits/images/99857262.jpg
#   inflating: polyvore_outfits/images/99858133.jpg
#   inflating: polyvore_outfits/images/99861145.jpg
#   inflating: polyvore_outfits/images/99861402.jpg
#   inflating: polyvore_outfits/images/99862014.jpg
#   inflating: polyvore_outfits/images/99862291.jpg
#   inflating: polyvore_outfits/images/99863528.jpg
#   inflating: polyvore_outfits/images/99867681.jpg
#   inflating: polyvore_outfits/images/99885091.jpg
#   inflating: polyvore_outfits/images/99888749.jpg
#   inflating: polyvore_outfits/images/99892164.jpg
#   inflating: polyvore_outfits/images/99892624.jpg
#   inflating: polyvore_outfits/images/99897794.jpg
#   inflating: polyvore_outfits/images/99900639.jpg
#   inflating: polyvore_outfits/images/99906301.jpg
#   inflating: polyvore_outfits/images/99908438.jpg
#   inflating: polyvore_outfits/images/99909375.jpg
#   inflating: polyvore_outfits/images/99909642.jpg
#   inflating: polyvore_outfits/images/99912403.jpg
#   inflating: polyvore_outfits/images/99912896.jpg
#   inflating: polyvore_outfits/images/99914141.jpg
#   inflating: polyvore_outfits/images/99916433.jpg
#   inflating: polyvore_outfits/images/99916987.jpg
#   inflating: polyvore_outfits/images/99917760.jpg
#   inflating: polyvore_outfits/images/99917811.jpg
#   inflating: polyvore_outfits/images/99918067.jpg
#   inflating: polyvore_outfits/images/99918284.jpg
#   inflating: polyvore_outfits/images/99918599.jpg
#   inflating: polyvore_outfits/images/99919728.jpg
#   inflating: polyvore_outfits/images/99920196.jpg
#   inflating: polyvore_outfits/images/99923242.jpg
#   inflating: polyvore_outfits/images/99924716.jpg
#   inflating: polyvore_outfits/images/99924764.jpg
#   inflating: polyvore_outfits/images/99929866.jpg
#   inflating: polyvore_outfits/images/99932834.jpg
#   inflating: polyvore_outfits/images/99933024.jpg
#   inflating: polyvore_outfits/images/99935163.jpg
#   inflating: polyvore_outfits/images/99935366.jpg
#   inflating: polyvore_outfits/images/99935619.jpg
#   inflating: polyvore_outfits/images/99935973.jpg
#   inflating: polyvore_outfits/images/99936646.jpg
#   inflating: polyvore_outfits/images/99936697.jpg
#   inflating: polyvore_outfits/images/99937072.jpg
#   inflating: polyvore_outfits/images/99937100.jpg
#   inflating: polyvore_outfits/images/99937550.jpg
#   inflating: polyvore_outfits/images/99938202.jpg
#   inflating: polyvore_outfits/images/99938964.jpg
#   inflating: polyvore_outfits/images/99939552.jpg
#   inflating: polyvore_outfits/images/99942384.jpg
#   inflating: polyvore_outfits/images/99943788.jpg
#   inflating: polyvore_outfits/images/99945480.jpg
#   inflating: polyvore_outfits/images/99949340.jpg
#   inflating: polyvore_outfits/images/99949546.jpg
#   inflating: polyvore_outfits/images/99957690.jpg
#   inflating: polyvore_outfits/images/99957742.jpg
#   inflating: polyvore_outfits/images/99961058.jpg
#   inflating: polyvore_outfits/images/99961112.jpg
#   inflating: polyvore_outfits/images/99961222.jpg
#   inflating: polyvore_outfits/images/99961578.jpg
#   inflating: polyvore_outfits/images/99961916.jpg
#   inflating: polyvore_outfits/images/99962758.jpg
#   inflating: polyvore_outfits/images/99962760.jpg
#   inflating: polyvore_outfits/images/99962842.jpg
#   inflating: polyvore_outfits/images/99963238.jpg
#   inflating: polyvore_outfits/images/99963356.jpg
#   inflating: polyvore_outfits/images/99964221.jpg
#   inflating: polyvore_outfits/images/99965006.jpg
#   inflating: polyvore_outfits/images/99967133.jpg
#   inflating: polyvore_outfits/images/9996806.jpg
#   inflating: polyvore_outfits/images/99968717.jpg
#   inflating: polyvore_outfits/images/99969391.jpg
#   inflating: polyvore_outfits/images/99969429.jpg
#   inflating: polyvore_outfits/images/99969655.jpg
#   inflating: polyvore_outfits/images/99969800.jpg
#   inflating: polyvore_outfits/images/99973285.jpg
#   inflating: polyvore_outfits/images/99973654.jpg
#   inflating: polyvore_outfits/images/99975146.jpg
#   inflating: polyvore_outfits/images/99981041.jpg
#   inflating: polyvore_outfits/images/99982684.jpg
#   inflating: polyvore_outfits/images/99982809.jpg
#   inflating: polyvore_outfits/images/99983742.jpg
#   inflating: polyvore_outfits/images/99984234.jpg
#   inflating: polyvore_outfits/images/99984306.jpg
#   inflating: polyvore_outfits/images/99984958.jpg
#   inflating: polyvore_outfits/images/99985765.jpg
#   inflating: polyvore_outfits/images/99986507.jpg
#   inflating: polyvore_outfits/images/99989419.jpg
#   inflating: polyvore_outfits/images/99989430.jpg
#   inflating: polyvore_outfits/images/99989757.jpg
#   inflating: polyvore_outfits/images/99990436.jpg
#   inflating: polyvore_outfits/images/99991996.jpg
#   inflating: polyvore_outfits/images/99992649.jpg
#   inflating: polyvore_outfits/maryland_polyvore_hardneg/compatibility_test.txt
#   inflating: polyvore_outfits/maryland_polyvore_hardneg/compatibility_train.txt
#   inflating: polyvore_outfits/maryland_polyvore_hardneg/compatibility_valid.txt
#   inflating: polyvore_outfits/maryland_polyvore_hardneg/fill_in_blank_test.json
#   inflating: polyvore_outfits/maryland_polyvore_hardneg/fill_in_blank_train.json
#   inflating: polyvore_outfits/maryland_polyvore_hardneg/fill_in_blank_valid.json
#   inflating: polyvore_outfits/nondisjoint/compatibility_test.txt
#   inflating: polyvore_outfits/nondisjoint/compatibility_train.txt
#   inflating: polyvore_outfits/nondisjoint/compatibility_valid.txt
#   inflating: polyvore_outfits/nondisjoint/fill_in_blank_test.json
#   inflating: polyvore_outfits/nondisjoint/fill_in_blank_train.json
#   inflating: polyvore_outfits/nondisjoint/fill_in_blank_valid.json
#   inflating: polyvore_outfits/nondisjoint/test.json
#   inflating: polyvore_outfits/nondisjoint/train.json
#   inflating: polyvore_outfits/nondisjoint/train_hglmm_pca6000.txt
#   inflating: polyvore_outfits/nondisjoint/typespaces.p
#   inflating: polyvore_outfits/nondisjoint/valid.json
#   inflating: polyvore_outfits/polyvore_item_metadata.json
#   inflating: polyvore_outfits/polyvore_outfit_titles.json

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import pathlib
import os
import tqdm
import glob
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from zipfile import ZipFile

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Zip Outfit Images to Drive

# %% [markdown]
# * For users conveninence save only outfit images from the dataset

# %%
file_paths = []
for root, directories, files in os.walk('/content/polyvore_outfits/images'):
    for file_name in files:
        file_path = os.path.join(root, file_name)
        file_paths.append(file_path)

# %%
len(file_paths)
# Out:
# 261057

# %%
with ZipFile('/content/drive/MyDrive/Outfit_Recommendation_Project/polyvore_outfits_images.zip', 'w') as zip:
    for file in file_paths:
        zip.write(file)

# %%
# !unzip "/content/drive/MyDrive/Outfit_Recommendation_Project/polyvore_outfits_images.zip"
# Out:
# Archive:  /content/drive/MyDrive/Outfit_Recommendation_Project/polyvore_outfits_images.zip
# replace content/polyvore_outfits/images/59820376.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# * Storing csv converted files into a single folder for easy retrieval of data

# %% [markdown]
# ##### polyvore_outfit_titles.json

# %%
polyvore_outfit_titles_df = pd.read_json('/content/polyvore_outfits/polyvore_outfit_titles.json')
polyvore_outfit_titles_df = polyvore_outfit_titles_df.T
polyvore_outfit_titles_df
# Out:
#                                 url_name                       title
# 219779031     spring trend colored denim               Denim Jumpers
# 211158670  boot scootin outfit only 2500          Stacked-Heel Boots
# 222049137               mermaid for life  "Mermaid Hair, Don't Care"
# 207880976   street style mini dress wrap               Blanket Wraps
# 171638917             high waisted jeans   High-Waisted Skinny Jeans
# ...                                  ...                         ...
# 209395792                  67 night guys   Apple Cider and Doughnuts
# 213634610                    dance party                 Dance Party
# 222597251                   friday night                Friday Night
# 179451388                 poncho in rain                Rain Ponchos
# 222089789    go sporty with twinkledeals                   Go Sporty
#
# [68306 rows x 2 columns]

# %%
polyvore_outfit_titles_df['outfit_id'] = polyvore_outfit_titles_df.index
polyvore_outfit_titles_df.reset_index(drop=True, inplace=True)

# %%
polyvore_outfit_titles_df.head(10)
# Out:
#                                   url_name                       title  \
# 0               spring trend colored denim               Denim Jumpers
# 1            boot scootin outfit only 2500          Stacked-Heel Boots
# 2                         mermaid for life  "Mermaid Hair, Don't Care"
# 3             street style mini dress wrap               Blanket Wraps
# 4                       high waisted jeans   High-Waisted Skinny Jeans
# 5                         casual statement            Chambray Dresses
# 6  lake studio floral stitched embroidered           Embroidered Coats
# 7               spring date made my friend                 Friend Date
# 8                              pack go rio                         Rio
# 9                      heres to everything             Holiday Fun Run
#
#    outfit_id
# 0  219779031
# 1  211158670
# 2  222049137
# 3  207880976
# 4  171638917
# 5   81476629
# 6  219905886
# 7  215768200
# 8  205180079
# 9   96522071

# %%
print(f'Total number of outfits = {polyvore_outfit_titles_df.shape[0]}')
# Out:
# Total number of outfits = 68306

# %%
polyvore_outfit_titles_df.to_csv('/content/drive/MyDrive/Outfit_Recommendation_Project/Data_CSV_Files/outfit_titles.csv', index=False)

# %% [markdown]
# ##### polyvore_item_metadata.json

# %%
polyvore_item_metadata_df = pd.read_json('/content/polyvore_outfits/polyvore_item_metadata.json')
polyvore_item_metadata_df
# Out:
#                                       211990161  \
# url_name           neck print chiffon plus size
# description
# catgeories
# title
# related
# category_id                                  15
# semantic_category                          tops
#
#                                                            183179503  \
# url_name               christian pellizzari floral jacquard trousers
# description        Gold and black silk blend floral jacquard trou...
# catgeories         [Women's Fashion, Clothing, Pants, Christian P...
# title                  Christian Pellizzari floral jacquard trousers
# related            [Floral pants, Grey pants, Print pants, Patter...
# category_id                                                       28
# semantic_category                                            bottoms
#
#                                              152771755  \
# url_name           natures jewelry stainless steel not
# description
# catgeories
# title
# related
# category_id                                         65
# semantic_category                            jewellery
#
#                                                            190445143  \
# url_name                             balmain women high waist flared
# description        Decorative gold colored buttons with lion deta...
# catgeories         [Women's Fashion, Clothing, Pants, Balmain pants]
# title                     Balmain Women High Waist Flared Knit Pants
# related            [Balmain, Flared pants, High-waisted pants, Kn...
# category_id                                                       28
# semantic_category                                            bottoms
#
#                                                            211444470  \
# url_name                               acler orson high waist belted
# description        This Acler Orson High Waist Belted Short featu...
# catgeories         [Women's Fashion, Clothing, Shorts, Marissa We...
# title                            Acler Orson High Waist Belted Short
# related            [Short shorts, High-waisted shorts, High rise ...
# category_id                                                       29
# semantic_category                                            bottoms
#
#                                                            192704091  \
# url_name                  christian louboutin girlystrappi bow 100mm
# description        Christian Louboutin patent leather and denim s...
# catgeories         [Women's Fashion, Shoes, Sandals, Christian Lo...
# title              Christian Louboutin Girlystrappi Bow 100mm Red...
# related            [Christian Louboutin, Red sole shoes, Patent l...
# category_id                                                       46
# semantic_category                                              shoes
#
#                                         117334561  \
# url_name           sacai luck cable knit cardigan
# description
# catgeories
# title
# related
# category_id                                    18
# semantic_category                       outerwear
#
#                                                            127403908  \
# url_name                                lapel loose woolen pink coat
# description        Pink Plain Coats Woolen Polyester Collar Fashi...
# catgeories             [Women's Fashion, Clothing, Outerwear, Coats]
# title                                   Lapel Loose Woolen Pink Coat
# related            [Woolen coat, Pink coat, Fur-collar wool coats...
# category_id                                                       24
# semantic_category                                          outerwear
#
#                                                            149817672  \
# url_name                             dolce gabbana roll neck sweater
# description        Black cashmere roll neck sweater  from Dolce &...
# catgeories         [Women's Fashion, Tops, Sweaters, Dolce&Gabban...
# title                              Dolce & Gabbana roll neck sweater
# related            [Dolce&Gabbana, Long sleeve tops, Rollneck swe...
# category_id                                                       19
# semantic_category                                               tops
#
#                                         210309753  ...  \
# url_name           rhinestone devil eye box chain  ...
# description                                        ...
# catgeories                                         ...
# title                                              ...
# related                                            ...
# category_id                                   106  ...
# semantic_category                       jewellery  ...
#
#                                                            201233356  \
# url_name                   pre-owned giuseppe zanotti suede platform
# description        Purple suede Giuseppe Zanotti platform sandals...
# catgeories         [Women's Fashion, Shoes, Sandals, Giuseppe Zan...
# title              Pre-owned Giuseppe Zanotti Suede Platform Sandals
# related            [Giuseppe Zanotti, Suede shoes, Purple shoes, ...
# category_id                                                       46
# semantic_category                                              shoes
#
#                                          129890527  \
# url_name           raga statement pendant necklace
# description
# catgeories
# title
# related
# category_id                                     62
# semantic_category                        jewellery
#
#                                     197205553  \
# url_name           belated punk zip up jacket
# description
# catgeories
# title
# related
# category_id                                25
# semantic_category                   outerwear
#
#                                                            142700536  \
# url_name                             red faux suede polished strappy
# description        Make sure to add these sexy heels to your coll...
# catgeories                           [Women's Fashion, Shoes, Pumps]
# title                 Red Faux Suede Polished Strappy Peep Toe Heels
# related            [Platform pumps, Red pumps, Peep toe pumps, Hi...
# category_id                                                       43
# semantic_category                                              shoes
#
#                                                     192169702  \
# url_name           jean skinny empi%C3%A8cement brod%C3%A9 la
# description
# catgeories
# title
# related
# category_id                                               237
# semantic_category                                     bottoms
#
#                                                            108411005  \
# url_name                       arnica embellished hand painted skirt
# description        Shop Stella Jean in our expertly curated in-se...
# catgeories         [Women's Fashion, Clothing, Skirts, Knee Lengt...
# title                          Arnica Embellished Hand Painted Skirt
# related                               [Red skirt, Embellished skirt]
# category_id                                                        9
# semantic_category                                            bottoms
#
#                                         212452593  \
# url_name           thom browne little boy knitted
# description
# catgeories
# title
# related
# category_id                                   236
# semantic_category                       outerwear
#
#                                            208651882  \
# url_name           colorful vortex print shawl scarf
# description
# catgeories
# title
# related
# category_id                                      105
# semantic_category                            scarves
#
#                                           209210426  \
# url_name           floral embroidered mesh see thru
# description
# catgeories
# title
# related
# category_id                                      11
# semantic_category                              tops
#
#                                                  181567392
# url_name           shein sheinside extreme destroyed denim
# description
# catgeories
# title
# related
# category_id                                             25
# semantic_category                                outerwear
#
# [7 rows x 251008 columns]

# %%
polyvore_item_metadata_df = polyvore_item_metadata_df.T
polyvore_item_metadata_df['item_id'] = polyvore_item_metadata_df.index
polyvore_item_metadata_df.reset_index(drop=True, inplace=True)

# %%
polyvore_item_metadata_df
# Out:
#                                              url_name  \
# 0                        neck print chiffon plus size
# 1       christian pellizzari floral jacquard trousers
# 2                 natures jewelry stainless steel not
# 3                     balmain women high waist flared
# 4                       acler orson high waist belted
# ...                                               ...
# 251003          arnica embellished hand painted skirt
# 251004                 thom browne little boy knitted
# 251005              colorful vortex print shawl scarf
# 251006               floral embroidered mesh see thru
# 251007        shein sheinside extreme destroyed denim
#
#                                               description  \
# 0
# 1       Gold and black silk blend floral jacquard trou...
# 2
# 3       Decorative gold colored buttons with lion deta...
# 4       This Acler Orson High Waist Belted Short featu...
# ...                                                   ...
# 251003  Shop Stella Jean in our expertly curated in-se...
# 251004
# 251005
# 251006
# 251007
#
#                                                catgeories  \
# 0
# 1       [Women's Fashion, Clothing, Pants, Christian P...
# 2
# 3       [Women's Fashion, Clothing, Pants, Balmain pants]
# 4       [Women's Fashion, Clothing, Shorts, Marissa We...
# ...                                                   ...
# 251003  [Women's Fashion, Clothing, Skirts, Knee Lengt...
# 251004
# 251005
# 251006
# 251007
#
#                                                 title  \
# 0
# 1       Christian Pellizzari floral jacquard trousers
# 2
# 3          Balmain Women High Waist Flared Knit Pants
# 4                 Acler Orson High Waist Belted Short
# ...                                               ...
# 251003          Arnica Embellished Hand Painted Skirt
# 251004
# 251005
# 251006
# 251007
#
#                                                   related category_id  \
# 0                                                                  15
# 1       [Floral pants, Grey pants, Print pants, Patter...          28
# 2                                                                  65
# 3       [Balmain, Flared pants, High-waisted pants, Kn...          28
# 4       [Short shorts, High-waisted shorts, High rise ...          29
# ...                                                   ...         ...
# 251003                     [Red skirt, Embellished skirt]           9
# 251004                                                            236
# 251005                                                            105
# 251006                                                             11
# 251007                                                             25
#
#        semantic_category    item_id
# 0                   tops  211990161
# 1                bottoms  183179503
# 2              jewellery  152771755
# 3                bottoms  190445143
# 4                bottoms  211444470
# ...                  ...        ...
# 251003           bottoms  108411005
# 251004         outerwear  212452593
# 251005           scarves  208651882
# 251006              tops  209210426
# 251007         outerwear  181567392
#
# [251008 rows x 8 columns]

# %%
polyvore_item_metadata_df.dtypes
# Out:
# url_name             object
# description          object
# catgeories           object
# title                object
# related              object
# category_id          object
# semantic_category    object
# item_id               int64
# dtype: object

# %%
print(f'Number of Items = {polyvore_item_metadata_df.shape[0]}')
# Out:
# Number of Items = 251008

# %%
print(f'Number of Images = {len(os.listdir("/content/content/polyvore_outfits/images"))}')
# Out:
# Number of Images = 261057

# %%
img = mpimg.imread('/content/content/polyvore_outfits/images/104934947.jpg')
plt.imshow(img)

# %%
polyvore_item_metadata_df.to_csv('/content/drive/MyDrive/Outfit_Recommendation_Project/Data_CSV_Files/item_metadata.csv', index=False)

# %% [markdown]
# ##### images

# %%
images_path = np.array(glob.glob('/content/content/polyvore_outfits/images'+'/'+'*.jpg'))
print(len(images_path))
print(images_path)
# Out:
# 261057
# ['/content/content/polyvore_outfits/images/59820376.jpg'
#  '/content/content/polyvore_outfits/images/206518930.jpg'
#  '/content/content/polyvore_outfits/images/159052074.jpg' ...
#  '/content/content/polyvore_outfits/images/180629225.jpg'
#  '/content/content/polyvore_outfits/images/193421769.jpg'
#  '/content/content/polyvore_outfits/images/165781745.jpg']

# %%
def get_item_id(img_path):
    item_file = os.path.basename(img_path)
    item_id = pathlib.Path(item_file).with_suffix("")
    return item_id.name

# %%
item_image_df = pd.DataFrame(columns=['item_id', 'item_image_path'])
item_image_df.item_image_path = images_path
item_image_df.item_id = item_image_df.item_image_path.apply(get_item_id)
item_image_df
# Out:
#           item_id                                    item_image_path
# 0        59820376  /content/content/polyvore_outfits/images/59820...
# 1       206518930  /content/content/polyvore_outfits/images/20651...
# 2       159052074  /content/content/polyvore_outfits/images/15905...
# 3       147491841  /content/content/polyvore_outfits/images/14749...
# 4       207480011  /content/content/polyvore_outfits/images/20748...
# ...           ...                                                ...
# 261052  149784213  /content/content/polyvore_outfits/images/14978...
# 261053  124261469  /content/content/polyvore_outfits/images/12426...
# 261054  180629225  /content/content/polyvore_outfits/images/18062...
# 261055  193421769  /content/content/polyvore_outfits/images/19342...
# 261056  165781745  /content/content/polyvore_outfits/images/16578...
#
# [261057 rows x 2 columns]

# %%
item_image_df.to_csv('/content/drive/MyDrive/Outfit_Recommendation_Project/Data_CSV_Files/item_image.csv', index=False)

# %% [markdown]
# ##### categories.csv

# %%
categories_df = pd.read_csv('/content/polyvore_outfits/categories.csv', header=0, names=['category_id', 'fine_grained_category', 'semantic_category'])
categories_df
# Out:
#      category_id fine_grained_category semantic_category
# 0              3                 dress          all-body
# 1              4                 dress          all-body
# 2              5                 dress          all-body
# 3              6                  gown          all-body
# 4              7                 skirt           bottoms
# ..           ...                   ...               ...
# 218         4495             sweathirt              tops
# 219         4495               sweater              tops
# 220         4496                hoodie              tops
# 221         4517          swimsuit top              tops
# 222         4518       swimsuit bottom           bottoms
#
# [223 rows x 3 columns]

# %%
categories_df.to_csv('/content/drive/MyDrive/Outfit_Recommendation_Project/Data_CSV_Files/categories.csv', index=False)

# %% [markdown]
# ##### Preparing Training Feature Data

# %%
items_id_list = item_image_df.item_id.to_numpy()
items_id_list
# Out:
# array(['59820376', '206518930', '159052074', ..., '180629225',
#        '193421769', '165781745'], dtype=object)

# %%
images_path_list = item_image_df.item_image_path.to_numpy()
images_path_list
# Out:
# array(['/content/content/polyvore_outfits/images/59820376.jpg',
#        '/content/content/polyvore_outfits/images/206518930.jpg',
#        '/content/content/polyvore_outfits/images/159052074.jpg', ...,
#        '/content/content/polyvore_outfits/images/180629225.jpg',
#        '/content/content/polyvore_outfits/images/193421769.jpg',
#        '/content/content/polyvore_outfits/images/165781745.jpg'],
#       dtype=object)

# %%
def build_outfit(row):

  dic_outfit={}
  for item_dict in row[0]:
    item_path = images_path_list[np.where(items_id_list == str(item_dict['item_id']))[0][0]]
    dic_outfit[f'{row[1]}_{item_dict["index"]}'] = item_path

  return dic_outfit

# %%
def arrange_images(image_dict):
    outfits_images_id = list(image_dict.keys())
    outfits_images_path = list(image_dict.values())

    return pd.DataFrame({'outfits_images_id':outfits_images_id, 'outfits_images_path':outfits_images_path})

# %%
disjiont_train_df = pd.read_json("/content/polyvore_outfits/disjoint/train.json")
disjiont_train_df
# Out:
#                                                    items     set_id
# 0      [{'item_id': '132621870', 'index': 1}, {'item_...  199244701
# 1      [{'item_id': '162715806', 'index': 1}, {'item_...  200742384
# 2      [{'item_id': '180028994', 'index': 1}, {'item_...  206955877
# 3      [{'item_id': '198643069', 'index': 1}, {'item_...  220340816
# 4      [{'item_id': '200139640', 'index': 1}, {'item_...  219393187
# ...                                                  ...        ...
# 16990  [{'item_id': '174197824', 'index': 1}, {'item_...  205231354
# 16991  [{'item_id': '189119660', 'index': 1}, {'item_...  211884833
# 16992  [{'item_id': '198170894', 'index': 1}, {'item_...  217542558
# 16993  [{'item_id': '180489704', 'index': 1}, {'item_...  205613256
# 16994  [{'item_id': '180383429', 'index': 1}, {'item_...  225327855
#
# [16995 rows x 2 columns]

# %%
disjiont_train_df.rename(columns = {'items' : 'outfit_items', 'set_id' : 'outfit_id'}, inplace = True)
print(disjiont_train_df.iloc[10,1])
disjiont_train_df.iloc[10,0]
# Out:
# 225139325
# [{'item_id': '213007746', 'index': 1},
#  {'item_id': '212992927', 'index': 2},
#  {'item_id': '214327110', 'index': 3},
#  {'item_id': '207668984', 'index': 4},
#  {'item_id': '181900351', 'index': 5},
#  {'item_id': '202212715', 'index': 6}]

# %%
disjiont_train_outfits_df=disjiont_train_df.copy()

for i in tqdm.tqdm(range(disjiont_train_outfits_df.shape[0])):
    disjiont_train_outfits_df.at[i,'outfit_items'] = build_outfit(disjiont_train_outfits_df.iloc[i])
# Out:
# 100%|██████████| 16995/16995 [28:40<00:00,  9.88it/s]

# %%
print(disjiont_train_outfits_df.iloc[10,1])
disjiont_train_outfits_df.iloc[10,0]
# Out:
# 225139325
# {'225139325_1': '/content/content/polyvore_outfits/images/213007746.jpg',
#  '225139325_2': '/content/content/polyvore_outfits/images/212992927.jpg',
#  '225139325_3': '/content/content/polyvore_outfits/images/214327110.jpg',
#  '225139325_4': '/content/content/polyvore_outfits/images/207668984.jpg',
#  '225139325_5': '/content/content/polyvore_outfits/images/181900351.jpg',
#  '225139325_6': '/content/content/polyvore_outfits/images/202212715.jpg'}

# %%
disjiont_train_outfits_df
# Out:
#                                             outfit_items  outfit_id
# 0      {'199244701_1': '/content/content/polyvore_out...  199244701
# 1      {'200742384_1': '/content/content/polyvore_out...  200742384
# 2      {'206955877_1': '/content/content/polyvore_out...  206955877
# 3      {'220340816_1': '/content/content/polyvore_out...  220340816
# 4      {'219393187_1': '/content/content/polyvore_out...  219393187
# ...                                                  ...        ...
# 16990  {'205231354_1': '/content/content/polyvore_out...  205231354
# 16991  {'211884833_1': '/content/content/polyvore_out...  211884833
# 16992  {'217542558_1': '/content/content/polyvore_out...  217542558
# 16993  {'205613256_1': '/content/content/polyvore_out...  205613256
# 16994  {'225327855_1': '/content/content/polyvore_out...  225327855
#
# [16995 rows x 2 columns]

# %%
disjiont_train_outfits_images = pd.DataFrame(columns=['outfits_images_id', 'outfits_images_path'])
for i in tqdm.tqdm(range(disjiont_train_outfits_df.shape[0])):
    disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# Out:
# Streaming output truncated to the last 5000 lines.
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
#  85%|████████▌ | 14501/16995 [02:35<00:37, 67.16it/s]<ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
#  85%|████████▌ | 14509/16995 [02:35<00:36, 67.94it/s]<ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
#  85%|████████▌ | 14517/16995 [02:35<00:35, 70.78it/s]<ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
#  85%|████████▌ | 14525/16995 [02:36<00:36, 67.84it/s]<ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
#  86%|████████▌ | 14532/16995 [02:36<00:36, 66.91it/s]<ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
#  86%|████████▌ | 14539/16995 [02:36<00:36, 67.14it/s]<ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
#  86%|████████▌ | 14546/16995 [02:36<00:37, 64.54it/s]<ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
#  86%|████████▌ | 14553/16995 [02:36<00:37, 65.82it/s]<ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
#  86%|████████▌ | 14560/16995 [02:36<00:36, 66.34it/s]<ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
#  86%|████████▌ | 14567/16995 [02:36<00:38, 62.85it/s]<ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
#  86%|████████▌ | 14574/16995 [02:36<00:39, 60.94it/s]<ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
#  86%|████████▌ | 14581/16995 [02:36<00:39, 61.47it/s]<ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
#  86%|████████▌ | 14588/16995 [02:37<00:40, 59.59it/s]<ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
#  86%|████████▌ | 14596/16995 [02:37<00:37, 63.36it/s]<ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
#  86%|████████▌ | 14603/16995 [02:37<00:37, 64.62it/s]<ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
#  86%|████████▌ | 14610/16995 [02:37<00:36, 66.05it/s]<ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
#  86%|████████▌ | 14618/16995 [02:37<00:34, 68.42it/s]<ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
#  86%|████████▌ | 14625/16995 [02:37<00:34, 68.18it/s]<ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
#  86%|████████▌ | 14633/16995 [02:37<00:33, 70.52it/s]<ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
#  86%|████████▌ | 14641/16995 [02:37<00:33, 70.01it/s]<ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# 100%|█████████▉| 16949/16995 [03:20<00:00, 51.08it/s]<ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# 100%|█████████▉| 16955/16995 [03:20<00:00, 52.64it/s]<ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# 100%|█████████▉| 16961/16995 [03:20<00:00, 49.11it/s]<ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# 100%|█████████▉| 16966/16995 [03:21<00:00, 47.72it/s]<ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# 100%|█████████▉| 16972/16995 [03:21<00:00, 49.68it/s]<ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# 100%|█████████▉| 16978/16995 [03:21<00:00, 48.89it/s]<ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# 100%|█████████▉| 16983/16995 [03:21<00:00, 48.24it/s]<ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# 100%|█████████▉| 16990/16995 [03:21<00:00, 52.26it/s]<ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-42-fd1f51264f52>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_train_outfits_images = disjiont_train_outfits_images.append(arrange_images(disjiont_train_outfits_df.iloc[i,0]), ignore_index=True)
# 100%|██████████| 16995/16995 [03:21<00:00, 84.30it/s]

# %%
disjiont_train_outfits_images
# Out:
#       outfits_images_id                                outfits_images_path
# 0           199244701_1  /content/content/polyvore_outfits/images/13262...
# 1           199244701_2  /content/content/polyvore_outfits/images/15396...
# 2           199244701_3  /content/content/polyvore_outfits/images/17116...
# 3           199244701_4  /content/content/polyvore_outfits/images/16279...
# 4           199244701_5  /content/content/polyvore_outfits/images/17253...
# ...                 ...                                                ...
# 85930       205613256_4  /content/content/polyvore_outfits/images/17596...
# 85931       205613256_5  /content/content/polyvore_outfits/images/16292...
# 85932       205613256_6  /content/content/polyvore_outfits/images/18060...
# 85933       225327855_1  /content/content/polyvore_outfits/images/18038...
# 85934       225327855_2  /content/content/polyvore_outfits/images/20191...
#
# [85935 rows x 2 columns]

# %%
disjiont_train_outfits_df.to_csv('/content/drive/MyDrive/Outfit_Recommendation_Project/Data_CSV_Files/disjiont_train_outfits.csv')

# %%
disjiont_train_outfits_images.to_csv('/content/drive/MyDrive/Outfit_Recommendation_Project/Data_CSV_Files/disjiont_train_outfits_images.csv', index=False)

# %% [markdown]
# ##### Preparing Test Feature Data

# %%
disjiont_test_df= pd.read_json("/content/polyvore_outfits/disjoint/test.json")
disjiont_test_df
# Out:
#                                                    items     set_id
# 0      [{'item_id': '159402796', 'index': 1}, {'item_...  222049137
# 1      [{'item_id': '58893791', 'index': 1}, {'item_i...  171638917
# 2      [{'item_id': '147772496', 'index': 1}, {'item_...  209614451
# 3      [{'item_id': '172213324', 'index': 1}, {'item_...  208805759
# 4      [{'item_id': '146453731', 'index': 1}, {'item_...  181727193
# ...                                                  ...        ...
# 15140  [{'item_id': '110258509', 'index': 1}, {'item_...  130442086
# 15141  [{'item_id': '159369228', 'index': 1}, {'item_...  191016735
# 15142  [{'item_id': '150478161', 'index': 1}, {'item_...  179451388
# 15143  [{'item_id': '32286230', 'index': 1}, {'item_i...   42911078
# 15144  [{'item_id': '189120927', 'index': 1}, {'item_...  210601169
#
# [15145 rows x 2 columns]

# %%
disjiont_test_df.rename(columns = {'items' : 'outfit_items', 'set_id' : 'outfit_id'}, inplace = True)
print(disjiont_test_df.iloc[100,1])
disjiont_test_df.iloc[100,0]
# Out:
# 191671357
# [{'item_id': '162281351', 'index': 1},
#  {'item_id': '162284763', 'index': 2},
#  {'item_id': '160720385', 'index': 3},
#  {'item_id': '158799041', 'index': 4},
#  {'item_id': '146340382', 'index': 5}]

# %%
disjiont_test_outfits_df=disjiont_test_df.copy()

for i in tqdm.tqdm(range(disjiont_test_outfits_df.shape[0])):
    disjiont_test_outfits_df.at[i,'outfit_items'] = build_outfit(disjiont_test_outfits_df.iloc[i])
# Out:
# 100%|██████████| 15145/15145 [25:45<00:00,  9.80it/s]

# %%
print(disjiont_test_outfits_df.iloc[100,1])
disjiont_test_outfits_df.iloc[100,0]
# Out:
# 191671357
# {'191671357_1': '/content/content/polyvore_outfits/images/162281351.jpg',
#  '191671357_2': '/content/content/polyvore_outfits/images/162284763.jpg',
#  '191671357_3': '/content/content/polyvore_outfits/images/160720385.jpg',
#  '191671357_4': '/content/content/polyvore_outfits/images/158799041.jpg',
#  '191671357_5': '/content/content/polyvore_outfits/images/146340382.jpg'}

# %%
disjiont_test_outfits_images = pd.DataFrame(columns=['outfits_images_id', 'outfits_images_path'])
for i in tqdm.tqdm(range(disjiont_test_outfits_df.shape[0])):
    disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# Out:
# Streaming output truncated to the last 5000 lines.
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
#  84%|████████▎ | 12650/15145 [01:57<00:35, 71.11it/s]<ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
#  84%|████████▎ | 12658/15145 [01:57<00:34, 72.59it/s]<ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
#  84%|████████▎ | 12666/15145 [01:57<00:33, 73.32it/s]<ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
#  84%|████████▎ | 12674/15145 [01:57<00:33, 72.88it/s]<ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
#  84%|████████▎ | 12682/15145 [01:57<00:33, 73.11it/s]<ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
#  84%|████████▍ | 12690/15145 [01:58<00:35, 68.21it/s]<ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
#  84%|████████▍ | 12699/15145 [01:58<00:34, 71.86it/s]<ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
#  84%|████████▍ | 12707/15145 [01:58<00:33, 71.73it/s]<ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
#  84%|████████▍ | 12715/15145 [01:58<00:34, 70.89it/s]<ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
#  84%|████████▍ | 12723/15145 [01:58<00:33, 72.78it/s]<ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
#  84%|████████▍ | 12732/15145 [01:58<00:32, 74.85it/s]<ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
#  84%|████████▍ | 12741/15145 [01:58<00:31, 76.99it/s]<ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
#  84%|████████▍ | 12749/15145 [01:58<00:33, 72.22it/s]<ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
#  84%|████████▍ | 12757/15145 [01:59<00:33, 70.77it/s]<ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
#  84%|████████▍ | 12765/15145 [01:59<00:33, 71.63it/s]<ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
#  84%|████████▍ | 12773/15145 [01:59<00:33, 70.61it/s]<ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
#  84%|████████▍ | 12781/15145 [01:59<00:32, 72.31it/s]<ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
#  84%|████████▍ | 12789/15145 [01:59<00:33, 70.50it/s]<ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
#  84%|████████▍ | 12797/15145 [01:59<00:33, 71.06it/s]<ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# ...
# 100%|█████████▉| 15095/15145 [02:36<00:00, 54.24it/s]<ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# 100%|█████████▉| 15101/15145 [02:36<00:00, 52.61it/s]<ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# 100%|█████████▉| 15108/15145 [02:36<00:00, 54.39it/s]<ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# 100%|█████████▉| 15114/15145 [02:36<00:00, 55.84it/s]<ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# 100%|█████████▉| 15120/15145 [02:37<00:00, 55.10it/s]<ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# 100%|█████████▉| 15126/15145 [02:37<00:00, 54.20it/s]<ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# 100%|█████████▉| 15132/15145 [02:37<00:00, 53.51it/s]<ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# 100%|█████████▉| 15138/15145 [02:37<00:00, 53.41it/s]<ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# 100%|█████████▉| 15144/15145 [02:37<00:00, 54.75it/s]<ipython-input-50-72e83b0e234e>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_test_outfits_images = disjiont_test_outfits_images.append(arrange_images(disjiont_test_outfits_df.iloc[i,0]), ignore_index=True)
# 100%|██████████| 15145/15145 [02:37<00:00, 96.16it/s]

# %%
disjiont_test_outfits_images
# Out:
#       outfits_images_id                                outfits_images_path
# 0           222049137_1  /content/content/polyvore_outfits/images/15940...
# 1           222049137_2  /content/content/polyvore_outfits/images/20081...
# 2           222049137_3  /content/content/polyvore_outfits/images/20888...
# 3           222049137_4  /content/content/polyvore_outfits/images/20889...
# 4           222049137_5  /content/content/polyvore_outfits/images/17683...
# ...                 ...                                                ...
# 74257        42911078_7  /content/content/polyvore_outfits/images/39806...
# 74258       210601169_1  /content/content/polyvore_outfits/images/18912...
# 74259       210601169_2  /content/content/polyvore_outfits/images/18912...
# 74260       210601169_3  /content/content/polyvore_outfits/images/18912...
# 74261       210601169_4  /content/content/polyvore_outfits/images/18912...
#
# [74262 rows x 2 columns]

# %%
disjiont_test_outfits_df.to_csv('/content/drive/MyDrive/Outfit_Recommendation_Project/Data_CSV_Files/disjiont_test_outfits.csv',index=False)

# %%
disjiont_test_outfits_images.to_csv('/content/drive/MyDrive/Outfit_Recommendation_Project/Data_CSV_Files/disjiont_test_outfits_images.csv', index=False)

# %% [markdown]
# ##### Preparing Validation Feature Data

# %%
disjiont_valid_df= pd.read_json("/content/polyvore_outfits/disjoint/valid.json")
disjiont_valid_df
# Out:
#                                                   items     set_id
# 0     [{'item_id': '211863963', 'index': 1}, {'item_...  223648758
# 1     [{'item_id': '194622168', 'index': 1}, {'item_...  219849644
# 2     [{'item_id': '184947151', 'index': 1}, {'item_...  208264087
# 3     [{'item_id': '117828723', 'index': 1}, {'item_...  135005113
# 4     [{'item_id': '196507149', 'index': 1}, {'item_...  216934649
# ...                                                 ...        ...
# 2995  [{'item_id': '191365709', 'index': 1}, {'item_...  221001144
# 2996  [{'item_id': '157133142', 'index': 1}, {'item_...  179889650
# 2997  [{'item_id': '48410374', 'index': 1}, {'item_i...  224578373
# 2998  [{'item_id': '164514051', 'index': 1}, {'item_...  198313686
# 2999  [{'item_id': '189281917', 'index': 1}, {'item_...  223051514
#
# [3000 rows x 2 columns]

# %%
disjiont_valid_df.rename(columns = {'items' : 'outfit_items', 'set_id' : 'outfit_id'}, inplace = True)
print(disjiont_valid_df.iloc[1000,1])
disjiont_valid_df.iloc[1000,0]
# Out:
# 212515017
# [{'item_id': '191695202', 'index': 1},
#  {'item_id': '194658747', 'index': 2},
#  {'item_id': '128427174', 'index': 3},
#  {'item_id': '146391713', 'index': 4},
#  {'item_id': '164208844', 'index': 5}]

# %%
disjiont_valid_outfits_df=disjiont_valid_df.copy()

for i in tqdm.tqdm(range(disjiont_valid_outfits_df.shape[0])):
    disjiont_valid_outfits_df.at[i,'outfit_items'] = build_outfit(disjiont_valid_outfits_df.iloc[i])
# Out:
# 100%|██████████| 3000/3000 [06:23<00:00,  7.83it/s]

# %%
print(disjiont_valid_outfits_df.iloc[1000,1])
disjiont_valid_outfits_df.iloc[1000,0]
# Out:
# 212515017
# {'212515017_1': '/content/content/polyvore_outfits/images/191695202.jpg',
#  '212515017_2': '/content/content/polyvore_outfits/images/194658747.jpg',
#  '212515017_3': '/content/content/polyvore_outfits/images/128427174.jpg',
#  '212515017_4': '/content/content/polyvore_outfits/images/146391713.jpg',
#  '212515017_5': '/content/content/polyvore_outfits/images/164208844.jpg'}

# %%
disjiont_valid_outfits_images = pd.DataFrame(columns=['outfits_images_id', 'outfits_images_path'])
for i in tqdm.tqdm(range(disjiont_valid_outfits_df.shape[0])):
    disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# Out:
# Streaming output truncated to the last 5000 lines.
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
#  17%|█▋        | 509/3000 [00:01<00:05, 454.92it/s]<ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
#  19%|█▊        | 556/3000 [00:01<00:05, 458.58it/s]<ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
#  20%|██        | 603/3000 [00:01<00:05, 416.51it/s]<ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
#  22%|██▏       | 646/3000 [00:01<00:06, 386.30it/s]<ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# ...
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
#  99%|█████████▉| 2967/3000 [00:11<00:00, 170.46it/s]<ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# 100%|█████████▉| 2985/3000 [00:11<00:00, 172.15it/s]<ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# <ipython-input-58-1e0773987cc0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disjiont_valid_outfits_images = disjiont_valid_outfits_images.append(arrange_images(disjiont_valid_outfits_df.iloc[i,0]), ignore_index=True)
# 100%|██████████| 3000/3000 [00:11<00:00, 252.74it/s]

# %%
disjiont_valid_outfits_df.to_csv('/content/drive/MyDrive/Outfit_Recommendation_Project/Data_CSV_Files/disjiont_valid_outfits.csv')

# %%
disjiont_valid_outfits_images.to_csv('/content/drive/MyDrive/Outfit_Recommendation_Project/Data_CSV_Files/disjiont_valid_outfits_images.csv', index=False)

# %% [markdown]
# ##### Preparing Test Target Data

# %%
with open('/content/polyvore_outfits/disjoint/compatibility_test.txt', 'r') as f:
    data = [line.split() for line in f]
    data = [(line[0] , [item for item in line[1:]]) for line in data]

compatibility_test_df = pd.DataFrame.from_records(data, columns=['compatibility', 'outfit_sample'])

compatibility_test_df
# Out:
#       compatibility                                      outfit_sample
# 0                 1  [222049137_1, 222049137_2, 222049137_3, 222049...
# 1                 1  [171638917_1, 171638917_2, 171638917_3, 171638...
# 2                 1  [209614451_1, 209614451_2, 209614451_3, 209614...
# 3                 1  [208805759_1, 208805759_2, 208805759_3, 208805...
# 4                 1  [181727193_1, 181727193_2, 181727193_3, 181727...
# ...             ...                                                ...
# 30285             0  [208697202_1, 222058995_1, 60152115_3, 9792134...
# 30286             0  [163646445_2, 154832568_2, 190013480_4, 214779...
# 30287             0  [145970783_1, 190480945_1, 212286826_4, 707638...
# 30288             0  [177747016_1, 178806147_2, 164069948_5, 209157...
# 30289             0  [217323982_1, 174060325_3, 206566023_3, 221349...
#
# [30290 rows x 2 columns]

# %%
compatibility_test_df.to_csv('/content/drive/MyDrive/Outfit_Recommendation_Project/Data_CSV_Files/disjoint_compatibility_test_outfits.csv',index=False)

# %% [markdown]
# ##### Preparing Train Target Data

# %%
with open('/content/polyvore_outfits/disjoint/compatibility_train.txt', 'r') as f:
    data = [line.split() for line in f]
    data = [(line[0] , [item for item in line[1:]]) for line in data]

compatibility_train_df = pd.DataFrame.from_records(data, columns=['compatibility', 'outfit_sample'])

compatibility_train_df
# Out:
#       compatibility                                      outfit_sample
# 0                 1  [199244701_1, 199244701_2, 199244701_3, 199244...
# 1                 1  [200742384_1, 200742384_2, 200742384_3, 200742...
# 2                 1  [206955877_1, 206955877_2, 206955877_3, 206955...
# 3                 1  [220340816_1, 220340816_2, 220340816_3, 220340...
# 4                 1  [219393187_1, 219393187_2, 219393187_3, 219393...
# ...             ...                                                ...
# 33985             0  [218506324_1, 221405016_1, 206461374_3, 218864...
# 33986             0  [105184990_1, 211494606_3, 204086912_4, 220595...
# 33987             0  [66630383_1, 132553628_1, 224927539_2, 2234803...
# 33988             0  [149252664_1, 224932578_2, 205854787_3, 206523...
# 33989             0                         [119274863_2, 211094404_4]
#
# [33990 rows x 2 columns]

# %%
compatibility_train_df.to_csv('/content/drive/MyDrive/Outfit_Recommendation_Project/Data_CSV_Files/disjoint_compatibility_train_outfits.csv',index=False)

# %% [markdown]
# ##### Preparing Validation Target Data

# %%
with open('/content/polyvore_outfits/disjoint/compatibility_valid.txt', 'r') as f:
    data = [line.split() for line in f]
    data = [(line[0] , [item for item in line[1:]]) for line in data]

compatibility_valid_df = pd.DataFrame.from_records(data, columns=['compatibility', 'outfit_sample'])

compatibility_valid_df
# Out:
#      compatibility                                      outfit_sample
# 0                1  [223648758_1, 223648758_2, 223648758_3, 223648...
# 1                1  [219849644_1, 219849644_2, 219849644_3, 219849...
# 2                1  [208264087_1, 208264087_2, 208264087_3, 208264...
# 3                1  [135005113_1, 135005113_2, 135005113_3, 135005...
# 4                1  [216934649_1, 216934649_2, 216934649_3, 216934...
# ...            ...                                                ...
# 5995             0  [215216859_1, 206870729_2, 209124426_3, 222275...
# 5996             0  [77811896_1, 207209295_2, 185443035_4, 1622178...
# 5997             0  [214362907_1, 225321688_3, 158405253_9, 209425...
# 5998             0  [209869925_1, 204014202_3, 200907615_2, 223147...
# 5999             0  [166260715_1, 149847684_2, 197296523_2, 215779...
#
# [6000 rows x 2 columns]

# %%
compatibility_valid_df.to_csv('/content/drive/MyDrive/Outfit_Recommendation_Project/Data_CSV_Files/disjoint_compatibility_valid_outfits.csv',index=False)
